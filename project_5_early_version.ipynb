# %% [markdown]
# #### Project 5: Zips Law distribution of Finnish Wikipedia Corpus.
#
# This project investigates various facets of the Zips law and how it can be empirically tested on a set of well known corpuses.

# %%
import zipfile
import requests
from io import BytesIO
import os, re, spacy
import glob
import pandas as pd
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy import stats
from pathlib import Path

# %%
# download database zip, extract, create iterable of VRT file-names

url = "https://www.kielipankki.fi/download/wikipedia-fi/wikipedia-fi-2017-src/wikipedia-fi-2017-src.zip"

if not os.path.exists("wikipedia-fi-2017-src"):
    zipfile.ZipFile(BytesIO(requests.get(url).content)).extractall()

files = glob.glob("wikipedia-fi-2017-src/wikipedia-fi-2017-src/*.VRT")

# %%
files = glob.glob("wikipedia-fi-2017-src/*.VRT")

# %% [markdown]
# Database of "wiki_part**.VRT" files: Universal Dependencies–style vertical (VRT/CoNLL-U hybrid) files.
#
# - Structural tags: \<doc\>, \<paragraph\>, \<sentence\>
#
# - Token lines: ID, FORM, LEMMA, UPOS, XPOS, FEATS, HEAD, DEPREL, DEPS, MISC
#
# Basically CoNLL-U tables wrapped in XML-like tags. \
# https://universaldependencies.org/docs/format.html

# %%
# create dataframe of a VRT file
def parse_vrt_to_df(path: str) -> pd.DataFrame:
    rows = []
    doc_id = None
    sent_id = 0

    tag_re = re.compile(r"<(/)?(\w+)(.*?)>")
    attr_re = re.compile(r'(\w+)="(.*?)"')

    with open(path, encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue

            # deal with XML
            if line.startswith("<"):
                m = tag_re.match(line)
                if not m:
                    continue
                closing, tagname, attrs_str = m.groups()

                # add document counter
                if not closing and tagname == "doc":
                    attrs = dict(attr_re.findall(attrs_str))
                    doc_id = attrs.get("id", None)

                # add sentence counter
                elif not closing and tagname == "sentence":
                    sent_id += 1
                continue

            # deal with tokens
            parts = line.split("\t")
            if len(parts) < 10:
                continue
            token_id, form, lemma, upos, xpos, feats, head, deprel, deps, misc = parts[:10]
            rows.append({
                "doc_id": doc_id,
                "sent_id": sent_id,
                "token_id": int(token_id),
                "form": form,
                "lemma": lemma,
                "upos": upos,
                "xpos": xpos if xpos != "_" else None,
                "feats": feats if feats != "_" else None,
                "head": int(head) if head.isdigit() else None,
                "deprel": deprel,
                "deps": deps if deps != "_" else None,
                "misc": misc if misc != "_" else None,
            })

    df = pd.DataFrame(rows)
    return df


# create dataframe of all VRT files
def create_df(files) -> pd.DataFrame:
    dfs = []
    for f in tqdm(files):
        dfs.append(parse_vrt_to_df(f))
    return pd.concat(dfs, ignore_index=True)

# %%
# takes a while (memory usage: 7.5+ GB)
df = create_df(files)
# Out:
#   0%|          | 0/66 [00:00<?, ?it/s]
# 100%|██████████| 66/66 [04:23<00:00,  3.99s/it]

# %%
# save dataframe as parquet file (took ~25min XD)
df.to_parquet("merged_corpus.parquet", index=False)

# %%
# load dataframe from parquet file (</~1min)
df = pd.read_parquet("merged_corpus.parquet")

# %%
# Only load part of the PARQUET file because it used too much RAM for my google collab

import pandas as pd

cols = ["doc_id","sent_id", "token_id", "form","upos"]
df = pd.read_parquet("merged_corpus.parquet", columns=cols)

df.head()
# Out:
#   doc_id  sent_id  token_id          form   upos
# 0      1        1         1     Amsterdam  PROPN
# 1      1        2         1     Amsterdam  PROPN
# 2      1        2         2            on   VERB
# 3      1        2         3  Alankomaiden  PROPN
# 4      1        2         4   pääkaupunki   NOUN

# %%
# I guess linked entities are the docs (wikipedia pages with url)?
# linked entities (documents): 425506

# series counts appearance of each doc_id i.e. number of tokens for each doc
vc = df['doc_id'].value_counts()
# len(series) == number of docs
print(f"Number of linked entities in dataset: {len(vc)}\n")
# counts per doc == tokens in doc
vc.index = vc.index.astype(int)
for v, c in vc.sort_index().items():
    print(f"Number of tokens in page of doc_id {v}: {c}")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Number of tokens in page of doc_id 1410907: 118
# Number of tokens in page of doc_id 1410908: 115
# Number of tokens in page of doc_id 1410909: 20
# Number of tokens in page of doc_id 1410913: 126
# Number of tokens in page of doc_id 1410915: 45
# Number of tokens in page of doc_id 1410916: 6
# Number of tokens in page of doc_id 1410923: 24
# Number of tokens in page of doc_id 1410926: 33
# Number of tokens in page of doc_id 1410931: 31
# Number of tokens in page of doc_id 1410932: 66
# Number of tokens in page of doc_id 1410936: 104
# Number of tokens in page of doc_id 1410944: 50
# Number of tokens in page of doc_id 1410952: 53
# Number of tokens in page of doc_id 1410966: 53
# Number of tokens in page of doc_id 1410968: 13
# Number of tokens in page of doc_id 1410969: 13
# Number of tokens in page of doc_id 1410970: 13
# Number of tokens in page of doc_id 1410972: 13
# Number of tokens in page of doc_id 1410973: 13
# Number of tokens in page of doc_id 1410974: 13
# Number of tokens in page of doc_id 1410975: 13
# Number of tokens in page of doc_id 1410976: 14
# Number of tokens in page of doc_id 1410977: 14
# Number of tokens in page of doc_id 1410978: 402
# Number of tokens in page of doc_id 1410979: 13
# Number of tokens in page of doc_id 1410980: 13
# Number of tokens in page of doc_id 1410981: 34
# Number of tokens in page of doc_id 1410982: 13
# Number of tokens in page of doc_id 1410983: 13
# Number of tokens in page of doc_id 1410984: 13
# Number of tokens in page of doc_id 1410985: 13
# Number of tokens in page of doc_id 1410986: 13
# Number of tokens in page of doc_id 1410987: 13
# Number of tokens in page of doc_id 1410988: 13
# Number of tokens in page of doc_id 1410989: 13
# Number of tokens in page of doc_id 1410990: 51
# Number of tokens in page of doc_id 1410991: 13
# Number of tokens in page of doc_id 1410993: 22
# Number of tokens in page of doc_id 1410994: 23
# Number of tokens in page of doc_id 1410995: 23
# Number of tokens in page of doc_id 1410996: 19
# Number of tokens in page of doc_id 1410997: 13
# Number of tokens in page of doc_id 1410998: 13
# Number of tokens in page of doc_id 1410999: 13
# Number of tokens in page of doc_id 1411000: 13
# Number of tokens in page of doc_id 1411001: 13
# Number of tokens in page of doc_id 1411002: 13
# Number of tokens in page of doc_id 1411007: 10
# Number of tokens in page of doc_id 1411008: 683
# Number of tokens in page of doc_id 1411009: 10
# Number of tokens in page of doc_id 1411010: 10
# Number of tokens in page of doc_id 1411012: 10
# Number of tokens in page of doc_id 1411013: 315
# Number of tokens in page of doc_id 1411014: 10
# Number of tokens in page of doc_id 1411015: 10
# Number of tokens in page of doc_id 1411017: 355
# Number of tokens in page of doc_id 1411018: 10
# Number of tokens in page of doc_id 1411020: 10
# Number of tokens in page of doc_id 1411021: 10
# Number of tokens in page of doc_id 1411022: 62
# Number of tokens in page of doc_id 1411023: 10
# Number of tokens in page of doc_id 1411026: 10
# Number of tokens in page of doc_id 1411027: 10
# Number of tokens in page of doc_id 1411028: 10
# Number of tokens in page of doc_id 1411029: 2039
# Number of tokens in page of doc_id 1411030: 10
# Number of tokens in page of doc_id 1411031: 10
# Number of tokens in page of doc_id 1411032: 10
# Number of tokens in page of doc_id 1411034: 12
# Number of tokens in page of doc_id 1411037: 10
# Number of tokens in page of doc_id 1411038: 415
# Number of tokens in page of doc_id 1411039: 10
# Number of tokens in page of doc_id 1411040: 10
# Number of tokens in page of doc_id 1411041: 208
# Number of tokens in page of doc_id 1411042: 10
# Number of tokens in page of doc_id 1411043: 10
# Number of tokens in page of doc_id 1411045: 194
# Number of tokens in page of doc_id 1411046: 10
# Number of tokens in page of doc_id 1411047: 260
# Number of tokens in page of doc_id 1411049: 10
# Number of tokens in page of doc_id 1411050: 315
# Number of tokens in page of doc_id 1411052: 194
# Number of tokens in page of doc_id 1411055: 10
# Number of tokens in page of doc_id 1411056: 159
# Number of tokens in page of doc_id 1411057: 10
# Number of tokens in page of doc_id 1411058: 10
# Number of tokens in page of doc_id 1411059: 10
# Number of tokens in page of doc_id 1411060: 10
# Number of tokens in page of doc_id 1411061: 10
# Number of tokens in page of doc_id 1411062: 10
# Number of tokens in page of doc_id 1411063: 242
# Number of tokens in page of doc_id 1411064: 10
# Number of tokens in page of doc_id 1411068: 10
# Number of tokens in page of doc_id 1411069: 578
# Number of tokens in page of doc_id 1411070: 10
# Number of tokens in page of doc_id 1411072: 10
# Number of tokens in page of doc_id 1411073: 10
# Number of tokens in page of doc_id 1411074: 10
# Number of tokens in page of doc_id 1411075: 10
# Number of tokens in page of doc_id 1411076: 10
# Number of tokens in page of doc_id 1411077: 10
# Number of tokens in page of doc_id 1411079: 10
# Number of tokens in page of doc_id 1411081: 10
# Number of tokens in page of doc_id 1411083: 311
# Number of tokens in page of doc_id 1411085: 10
# Number of tokens in page of doc_id 1411086: 10
# Number of tokens in page of doc_id 1411087: 10
# Number of tokens in page of doc_id 1411088: 10
# Number of tokens in page of doc_id 1411089: 10
# Number of tokens in page of doc_id 1411090: 10
# Number of tokens in page of doc_id 1411091: 10
# Number of tokens in page of doc_id 1411093: 36
# Number of tokens in page of doc_id 1411094: 10
# Number of tokens in page of doc_id 1411095: 67
# Number of tokens in page of doc_id 1411096: 10
# Number of tokens in page of doc_id 1411097: 10
# Number of tokens in page of doc_id 1411098: 10
# Number of tokens in page of doc_id 1411099: 10
# Number of tokens in page of doc_id 1411101: 10
# Number of tokens in page of doc_id 1411102: 10
# Number of tokens in page of doc_id 1411103: 10
# Number of tokens in page of doc_id 1411105: 10
# Number of tokens in page of doc_id 1411108: 10
# Number of tokens in page of doc_id 1411109: 10
# Number of tokens in page of doc_id 1411111: 10
# Number of tokens in page of doc_id 1411112: 10
# Number of tokens in page of doc_id 1411113: 10
# Number of tokens in page of doc_id 1411114: 10
# Number of tokens in page of doc_id 1411115: 10
# Number of tokens in page of doc_id 1411116: 10
# Number of tokens in page of doc_id 1411117: 10
# Number of tokens in page of doc_id 1411119: 10
# Number of tokens in page of doc_id 1411122: 10
# Number of tokens in page of doc_id 1411123: 149
# Number of tokens in page of doc_id 1411124: 10
# Number of tokens in page of doc_id 1411125: 10
# Number of tokens in page of doc_id 1411126: 10
# Number of tokens in page of doc_id 1411127: 10
# Number of tokens in page of doc_id 1411128: 10
# Number of tokens in page of doc_id 1411129: 10
# Number of tokens in page of doc_id 1411130: 10
# Number of tokens in page of doc_id 1411131: 10
# Number of tokens in page of doc_id 1411133: 10
# Number of tokens in page of doc_id 1411134: 66
# Number of tokens in page of doc_id 1411136: 142
# Number of tokens in page of doc_id 1411140: 55
# Number of tokens in page of doc_id 1411143: 161
# Number of tokens in page of doc_id 1411147: 442
# Number of tokens in page of doc_id 1411149: 85
# Number of tokens in page of doc_id 1411151: 305
# Number of tokens in page of doc_id 1411152: 48
# Number of tokens in page of doc_id 1411161: 351
# Number of tokens in page of doc_id 1411165: 63
# Number of tokens in page of doc_id 1411171: 60
# Number of tokens in page of doc_id 1411172: 137
# Number of tokens in page of doc_id 1411174: 80
# Number of tokens in page of doc_id 1411175: 580
# Number of tokens in page of doc_id 1411177: 55
# Number of tokens in page of doc_id 1411178: 174
# Number of tokens in page of doc_id 1411182: 76
# Number of tokens in page of doc_id 1411184: 277
# Number of tokens in page of doc_id 1411187: 6
# Number of tokens in page of doc_id 1411190: 15
# Number of tokens in page of doc_id 1411194: 370
# Number of tokens in page of doc_id 1411213: 20
# Number of tokens in page of doc_id 1411214: 402
# Number of tokens in page of doc_id 1411216: 262
# Number of tokens in page of doc_id 1411217: 164
# Number of tokens in page of doc_id 1411221: 84
# Number of tokens in page of doc_id 1411223: 263
# Number of tokens in page of doc_id 1411226: 174
# Number of tokens in page of doc_id 1411227: 94
# Number of tokens in page of doc_id 1411228: 34
# Number of tokens in page of doc_id 1411229: 118
# Number of tokens in page of doc_id 1411230: 44
# Number of tokens in page of doc_id 1411242: 9
# Number of tokens in page of doc_id 1411245: 9
# Number of tokens in page of doc_id 1411249: 488
# Number of tokens in page of doc_id 1411250: 6
# Number of tokens in page of doc_id 1411255: 356
# Number of tokens in page of doc_id 1411257: 66
# Number of tokens in page of doc_id 1411260: 47
# Number of tokens in page of doc_id 1411264: 151
# Number of tokens in page of doc_id 1411269: 213
# Number of tokens in page of doc_id 1411270: 9
# Number of tokens in page of doc_id 1411271: 253
# Number of tokens in page of doc_id 1411274: 124
# Number of tokens in page of doc_id 1411275: 67
# Number of tokens in page of doc_id 1411276: 634
# Number of tokens in page of doc_id 1411277: 402
# Number of tokens in page of doc_id 1411278: 968
# Number of tokens in page of doc_id 1411279: 543
# Number of tokens in page of doc_id 1411281: 110
# Number of tokens in page of doc_id 1411282: 895
# Number of tokens in page of doc_id 1411284: 125
# Number of tokens in page of doc_id 1411289: 469
# Number of tokens in page of doc_id 1411293: 406
# Number of tokens in page of doc_id 1411294: 431
# Number of tokens in page of doc_id 1411297: 83
# Number of tokens in page of doc_id 1411298: 339
# Number of tokens in page of doc_id 1411300: 177
# Number of tokens in page of doc_id 1411304: 138
# Number of tokens in page of doc_id 1411305: 203
# Number of tokens in page of doc_id 1411306: 9
# Number of tokens in page of doc_id 1411309: 90
# Number of tokens in page of doc_id 1411312: 605
# Number of tokens in page of doc_id 1411318: 73
# Number of tokens in page of doc_id 1411321: 36
# Number of tokens in page of doc_id 1411323: 38
# Number of tokens in page of doc_id 1411324: 133
# Number of tokens in page of doc_id 1411326: 72
# Number of tokens in page of doc_id 1411327: 191
# Number of tokens in page of doc_id 1411328: 60
# Number of tokens in page of doc_id 1411330: 24
# Number of tokens in page of doc_id 1411332: 222
# Number of tokens in page of doc_id 1411333: 118
# Number of tokens in page of doc_id 1411335: 239
# Number of tokens in page of doc_id 1411336: 186
# Number of tokens in page of doc_id 1411337: 404
# Number of tokens in page of doc_id 1411343: 385
# Number of tokens in page of doc_id 1411345: 313
# Number of tokens in page of doc_id 1411347: 394
# Number of tokens in page of doc_id 1411350: 585
# Number of tokens in page of doc_id 1411352: 299
# Number of tokens in page of doc_id 1411356: 344
# Number of tokens in page of doc_id 1411365: 112
# Number of tokens in page of doc_id 1411368: 210
# Number of tokens in page of doc_id 1411379: 32
# Number of tokens in page of doc_id 1411380: 49
# Number of tokens in page of doc_id 1411385: 46
# Number of tokens in page of doc_id 1411386: 47
# Number of tokens in page of doc_id 1411387: 231
# Number of tokens in page of doc_id 1411399: 211
# Number of tokens in page of doc_id 1411403: 1201
# Number of tokens in page of doc_id 1411405: 344
# Number of tokens in page of doc_id 1411406: 228
# Number of tokens in page of doc_id 1411415: 91
# Number of tokens in page of doc_id 1411419: 66
# Number of tokens in page of doc_id 1411420: 58
# Number of tokens in page of doc_id 1411423: 128
# Number of tokens in page of doc_id 1411426: 77
# Number of tokens in page of doc_id 1411427: 288
# Number of tokens in page of doc_id 1411428: 162
# Number of tokens in page of doc_id 1411430: 449
# Number of tokens in page of doc_id 1411433: 34
# Number of tokens in page of doc_id 1411441: 274
# Number of tokens in page of doc_id 1411445: 874
# Number of tokens in page of doc_id 1411446: 245
# Number of tokens in page of doc_id 1411449: 166
# Number of tokens in page of doc_id 1411452: 28
# Number of tokens in page of doc_id 1411456: 87
# Number of tokens in page of doc_id 1411458: 318
# Number of tokens in page of doc_id 1411460: 291
# Number of tokens in page of doc_id 1411462: 627
# Number of tokens in page of doc_id 1411469: 536
# Number of tokens in page of doc_id 1411474: 278
# Number of tokens in page of doc_id 1411477: 508
# Number of tokens in page of doc_id 1411484: 498
# Number of tokens in page of doc_id 1411490: 495
# Number of tokens in page of doc_id 1411493: 216
# Number of tokens in page of doc_id 1411494: 398
# Number of tokens in page of doc_id 1411495: 28
# Number of tokens in page of doc_id 1411496: 61
# Number of tokens in page of doc_id 1411497: 486
# Number of tokens in page of doc_id 1411503: 57
# Number of tokens in page of doc_id 1411511: 17
# Number of tokens in page of doc_id 1411513: 183
# Number of tokens in page of doc_id 1411514: 192
# Number of tokens in page of doc_id 1411516: 48
# Number of tokens in page of doc_id 1411517: 119
# Number of tokens in page of doc_id 1411518: 188
# Number of tokens in page of doc_id 1411519: 155
# Number of tokens in page of doc_id 1411524: 168
# Number of tokens in page of doc_id 1411525: 382
# Number of tokens in page of doc_id 1411529: 40
# Number of tokens in page of doc_id 1411530: 147
# Number of tokens in page of doc_id 1411533: 32
# Number of tokens in page of doc_id 1411535: 31
# Number of tokens in page of doc_id 1411536: 65
# Number of tokens in page of doc_id 1411537: 36
# Number of tokens in page of doc_id 1411538: 52
# Number of tokens in page of doc_id 1411539: 24
# Number of tokens in page of doc_id 1411542: 7
# Number of tokens in page of doc_id 1411543: 25
# Number of tokens in page of doc_id 1411544: 25
# Number of tokens in page of doc_id 1411547: 50
# Number of tokens in page of doc_id 1411550: 40
# Number of tokens in page of doc_id 1411551: 35
# Number of tokens in page of doc_id 1411552: 35
# Number of tokens in page of doc_id 1411554: 31
# Number of tokens in page of doc_id 1411555: 41
# Number of tokens in page of doc_id 1411556: 52
# Number of tokens in page of doc_id 1411557: 39
# Number of tokens in page of doc_id 1411558: 34
# Number of tokens in page of doc_id 1411560: 39
# Number of tokens in page of doc_id 1411562: 53
# Number of tokens in page of doc_id 1411563: 34
# Number of tokens in page of doc_id 1411565: 38
# Number of tokens in page of doc_id 1411566: 36
# Number of tokens in page of doc_id 1411567: 34
# Number of tokens in page of doc_id 1411569: 42
# Number of tokens in page of doc_id 1411570: 34
# Number of tokens in page of doc_id 1411572: 36
# Number of tokens in page of doc_id 1411573: 34
# Number of tokens in page of doc_id 1411574: 36
# Number of tokens in page of doc_id 1411576: 36
# Number of tokens in page of doc_id 1411577: 36
# Number of tokens in page of doc_id 1411578: 34
# Number of tokens in page of doc_id 1411579: 36
# Number of tokens in page of doc_id 1411580: 31
# Number of tokens in page of doc_id 1411581: 38
# Number of tokens in page of doc_id 1411582: 39
# Number of tokens in page of doc_id 1411583: 41
# Number of tokens in page of doc_id 1411584: 42
# Number of tokens in page of doc_id 1411585: 34
# Number of tokens in page of doc_id 1411596: 44
# Number of tokens in page of doc_id 1411598: 35
# Number of tokens in page of doc_id 1411599: 33
# Number of tokens in page of doc_id 1411604: 110
# Number of tokens in page of doc_id 1411607: 98
# Number of tokens in page of doc_id 1411609: 38
# Number of tokens in page of doc_id 1411611: 1036
# Number of tokens in page of doc_id 1411618: 623
# Number of tokens in page of doc_id 1411626: 435
# Number of tokens in page of doc_id 1411628: 61
# Number of tokens in page of doc_id 1411630: 77
# Number of tokens in page of doc_id 1411647: 466
# Number of tokens in page of doc_id 1411651: 45
# Number of tokens in page of doc_id 1411654: 42
# Number of tokens in page of doc_id 1411656: 67
# Number of tokens in page of doc_id 1411657: 63
# Number of tokens in page of doc_id 1411658: 51
# Number of tokens in page of doc_id 1411661: 70
# Number of tokens in page of doc_id 1411664: 76
# Number of tokens in page of doc_id 1411666: 66
# Number of tokens in page of doc_id 1411670: 102
# Number of tokens in page of doc_id 1411671: 115
# Number of tokens in page of doc_id 1411673: 48
# Number of tokens in page of doc_id 1411674: 12
# Number of tokens in page of doc_id 1411678: 227
# Number of tokens in page of doc_id 1411680: 250
# Number of tokens in page of doc_id 1411682: 1311
# Number of tokens in page of doc_id 1411684: 394
# Number of tokens in page of doc_id 1411686: 219
# Number of tokens in page of doc_id 1411687: 13
# Number of tokens in page of doc_id 1411688: 432
# Number of tokens in page of doc_id 1411689: 109
# Number of tokens in page of doc_id 1411693: 476
# Number of tokens in page of doc_id 1411698: 260
# Number of tokens in page of doc_id 1411702: 8
# Number of tokens in page of doc_id 1411703: 308
# Number of tokens in page of doc_id 1411704: 355
# Number of tokens in page of doc_id 1411707: 1152
# Number of tokens in page of doc_id 1411708: 192
# Number of tokens in page of doc_id 1411711: 810
# Number of tokens in page of doc_id 1411712: 558
# Number of tokens in page of doc_id 1411716: 78
# Number of tokens in page of doc_id 1411718: 39
# Number of tokens in page of doc_id 1411720: 139
# Number of tokens in page of doc_id 1411722: 10
# Number of tokens in page of doc_id 1411724: 61
# Number of tokens in page of doc_id 1411725: 10
# Number of tokens in page of doc_id 1411726: 75
# Number of tokens in page of doc_id 1411729: 24
# Number of tokens in page of doc_id 1411731: 24
# Number of tokens in page of doc_id 1411732: 89
# Number of tokens in page of doc_id 1411733: 109
# Number of tokens in page of doc_id 1411735: 206
# Number of tokens in page of doc_id 1411738: 210
# Number of tokens in page of doc_id 1411739: 131
# Number of tokens in page of doc_id 1411740: 274
# Number of tokens in page of doc_id 1411744: 293
# Number of tokens in page of doc_id 1411747: 133
# Number of tokens in page of doc_id 1411751: 574
# Number of tokens in page of doc_id 1411761: 184
# Number of tokens in page of doc_id 1411763: 48
# Number of tokens in page of doc_id 1411767: 121
# Number of tokens in page of doc_id 1411769: 58
# Number of tokens in page of doc_id 1411771: 225
# Number of tokens in page of doc_id 1411772: 215
# Number of tokens in page of doc_id 1411774: 75
# Number of tokens in page of doc_id 1411776: 1065
# Number of tokens in page of doc_id 1411781: 188
# Number of tokens in page of doc_id 1411797: 44
# Number of tokens in page of doc_id 1411798: 74
# Number of tokens in page of doc_id 1411799: 10
# Number of tokens in page of doc_id 1411800: 16
# Number of tokens in page of doc_id 1411804: 38
# Number of tokens in page of doc_id 1411806: 18
# Number of tokens in page of doc_id 1411809: 107
# Number of tokens in page of doc_id 1411810: 272
# Number of tokens in page of doc_id 1411815: 1728
# Number of tokens in page of doc_id 1411817: 180
# Number of tokens in page of doc_id 1411825: 79
# Number of tokens in page of doc_id 1411827: 345
# Number of tokens in page of doc_id 1411828: 16
# Number of tokens in page of doc_id 1411829: 33
# Number of tokens in page of doc_id 1411830: 287
# Number of tokens in page of doc_id 1411832: 357
# Number of tokens in page of doc_id 1411836: 65
# Number of tokens in page of doc_id 1411837: 253
# Number of tokens in page of doc_id 1411838: 116
# Number of tokens in page of doc_id 1411841: 65
# Number of tokens in page of doc_id 1411843: 201
# Number of tokens in page of doc_id 1411844: 62
# Number of tokens in page of doc_id 1411846: 20
# Number of tokens in page of doc_id 1411847: 102
# Number of tokens in page of doc_id 1411849: 46
# Number of tokens in page of doc_id 1411852: 24
# Number of tokens in page of doc_id 1411853: 42
# Number of tokens in page of doc_id 1411855: 27
# Number of tokens in page of doc_id 1411857: 70
# Number of tokens in page of doc_id 1411861: 31
# Number of tokens in page of doc_id 1411863: 35
# Number of tokens in page of doc_id 1411865: 55
# Number of tokens in page of doc_id 1411867: 180
# Number of tokens in page of doc_id 1411869: 51
# Number of tokens in page of doc_id 1411871: 37
# Number of tokens in page of doc_id 1411872: 72
# Number of tokens in page of doc_id 1411875: 63
# Number of tokens in page of doc_id 1411880: 132
# Number of tokens in page of doc_id 1411888: 105
# Number of tokens in page of doc_id 1411889: 13
# Number of tokens in page of doc_id 1411894: 107
# Number of tokens in page of doc_id 1411895: 13
# Number of tokens in page of doc_id 1411903: 68
# Number of tokens in page of doc_id 1411905: 41
# Number of tokens in page of doc_id 1411909: 83
# Number of tokens in page of doc_id 1411917: 140
# Number of tokens in page of doc_id 1411918: 411
# Number of tokens in page of doc_id 1411922: 521
# Number of tokens in page of doc_id 1411924: 161
# Number of tokens in page of doc_id 1411926: 57
# Number of tokens in page of doc_id 1411930: 119
# Number of tokens in page of doc_id 1411935: 91
# Number of tokens in page of doc_id 1411940: 33
# Number of tokens in page of doc_id 1411943: 239
# Number of tokens in page of doc_id 1411948: 31
# Number of tokens in page of doc_id 1411949: 223
# Number of tokens in page of doc_id 1411950: 128
# Number of tokens in page of doc_id 1411954: 52
# Number of tokens in page of doc_id 1411956: 44
# Number of tokens in page of doc_id 1411967: 71
# Number of tokens in page of doc_id 1411972: 34
# Number of tokens in page of doc_id 1411973: 90
# Number of tokens in page of doc_id 1411982: 45
# Number of tokens in page of doc_id 1411985: 63
# Number of tokens in page of doc_id 1411988: 75
# Number of tokens in page of doc_id 1411995: 147
# Number of tokens in page of doc_id 1411996: 639
# Number of tokens in page of doc_id 1412011: 578
# Number of tokens in page of doc_id 1412012: 234
# Number of tokens in page of doc_id 1412013: 147
# Number of tokens in page of doc_id 1412014: 61
# Number of tokens in page of doc_id 1412027: 411
# Number of tokens in page of doc_id 1412028: 298
# Number of tokens in page of doc_id 1412030: 88
# Number of tokens in page of doc_id 1412032: 43
# Number of tokens in page of doc_id 1412033: 91
# Number of tokens in page of doc_id 1412035: 43
# Number of tokens in page of doc_id 1412041: 78
# Number of tokens in page of doc_id 1412042: 654
# Number of tokens in page of doc_id 1412045: 509
# Number of tokens in page of doc_id 1412046: 336
# Number of tokens in page of doc_id 1412047: 365
# Number of tokens in page of doc_id 1412057: 26
# Number of tokens in page of doc_id 1412059: 62
# Number of tokens in page of doc_id 1412071: 19
# Number of tokens in page of doc_id 1412072: 28
# Number of tokens in page of doc_id 1412076: 27
# Number of tokens in page of doc_id 1412079: 26
# Number of tokens in page of doc_id 1412080: 362
# Number of tokens in page of doc_id 1412081: 29
# Number of tokens in page of doc_id 1412082: 107
# Number of tokens in page of doc_id 1412084: 106
# Number of tokens in page of doc_id 1412091: 198
# Number of tokens in page of doc_id 1412095: 207
# Number of tokens in page of doc_id 1412099: 285
# Number of tokens in page of doc_id 1412100: 34
# Number of tokens in page of doc_id 1412104: 87
# Number of tokens in page of doc_id 1412106: 198
# Number of tokens in page of doc_id 1412111: 39
# Number of tokens in page of doc_id 1412113: 33
# Number of tokens in page of doc_id 1412118: 214
# Number of tokens in page of doc_id 1412123: 43
# Number of tokens in page of doc_id 1412125: 250
# Number of tokens in page of doc_id 1412129: 1287
# Number of tokens in page of doc_id 1412131: 82
# Number of tokens in page of doc_id 1412133: 199
# Number of tokens in page of doc_id 1412136: 246
# Number of tokens in page of doc_id 1412138: 37
# Number of tokens in page of doc_id 1412139: 171
# Number of tokens in page of doc_id 1412140: 655
# Number of tokens in page of doc_id 1412145: 205
# Number of tokens in page of doc_id 1412152: 101
# Number of tokens in page of doc_id 1412153: 39
# Number of tokens in page of doc_id 1412155: 45
# Number of tokens in page of doc_id 1412156: 339
# Number of tokens in page of doc_id 1412161: 28
# Number of tokens in page of doc_id 1412163: 436
# Number of tokens in page of doc_id 1412167: 45
# Number of tokens in page of doc_id 1412168: 33
# Number of tokens in page of doc_id 1412169: 126
# Number of tokens in page of doc_id 1412171: 136
# Number of tokens in page of doc_id 1412175: 175
# Number of tokens in page of doc_id 1412178: 103
# Number of tokens in page of doc_id 1412180: 145
# Number of tokens in page of doc_id 1412181: 108
# Number of tokens in page of doc_id 1412182: 49
# Number of tokens in page of doc_id 1412186: 49
# Number of tokens in page of doc_id 1412191: 22
# Number of tokens in page of doc_id 1412196: 43
# Number of tokens in page of doc_id 1412197: 33
# Number of tokens in page of doc_id 1412200: 281
# Number of tokens in page of doc_id 1412201: 208
# Number of tokens in page of doc_id 1412206: 49
# Number of tokens in page of doc_id 1412209: 424
# Number of tokens in page of doc_id 1412211: 44
# Number of tokens in page of doc_id 1412215: 74
# Number of tokens in page of doc_id 1412216: 26
# Number of tokens in page of doc_id 1412217: 172
# Number of tokens in page of doc_id 1412218: 257
# Number of tokens in page of doc_id 1412222: 81
# Number of tokens in page of doc_id 1412225: 23
# Number of tokens in page of doc_id 1412227: 341
# Number of tokens in page of doc_id 1412231: 54
# Number of tokens in page of doc_id 1412236: 22
# Number of tokens in page of doc_id 1412237: 74
# Number of tokens in page of doc_id 1412238: 41
# Number of tokens in page of doc_id 1412242: 251
# Number of tokens in page of doc_id 1412244: 596
# Number of tokens in page of doc_id 1412250: 613
# Number of tokens in page of doc_id 1412251: 209
# Number of tokens in page of doc_id 1412252: 133
# Number of tokens in page of doc_id 1412257: 209
# Number of tokens in page of doc_id 1412261: 25
# Number of tokens in page of doc_id 1412266: 349
# Number of tokens in page of doc_id 1412268: 42
# Number of tokens in page of doc_id 1412269: 78
# Number of tokens in page of doc_id 1412275: 350
# Number of tokens in page of doc_id 1412277: 231
# Number of tokens in page of doc_id 1412278: 1351
# Number of tokens in page of doc_id 1412279: 25
# Number of tokens in page of doc_id 1412280: 62
# Number of tokens in page of doc_id 1412283: 145
# Number of tokens in page of doc_id 1412286: 93
# Number of tokens in page of doc_id 1412288: 251
# Number of tokens in page of doc_id 1412291: 106
# Number of tokens in page of doc_id 1412298: 271
# Number of tokens in page of doc_id 1412299: 312
# Number of tokens in page of doc_id 1412300: 179
# Number of tokens in page of doc_id 1412307: 102
# Number of tokens in page of doc_id 1412309: 75
# Number of tokens in page of doc_id 1412311: 59
# Number of tokens in page of doc_id 1412312: 54
# Number of tokens in page of doc_id 1412313: 53
# Number of tokens in page of doc_id 1412320: 137
# Number of tokens in page of doc_id 1412322: 34
# Number of tokens in page of doc_id 1412324: 94
# Number of tokens in page of doc_id 1412331: 103
# Number of tokens in page of doc_id 1412333: 191
# Number of tokens in page of doc_id 1412334: 107
# Number of tokens in page of doc_id 1412336: 399
# Number of tokens in page of doc_id 1412337: 41
# Number of tokens in page of doc_id 1412338: 13
# Number of tokens in page of doc_id 1412339: 16
# Number of tokens in page of doc_id 1412340: 13
# Number of tokens in page of doc_id 1412341: 41
# Number of tokens in page of doc_id 1412343: 13
# Number of tokens in page of doc_id 1412344: 13
# Number of tokens in page of doc_id 1412345: 13
# Number of tokens in page of doc_id 1412346: 13
# Number of tokens in page of doc_id 1412348: 13
# Number of tokens in page of doc_id 1412351: 13
# Number of tokens in page of doc_id 1412352: 13
# Number of tokens in page of doc_id 1412353: 13
# Number of tokens in page of doc_id 1412354: 13
# Number of tokens in page of doc_id 1412355: 13
# Number of tokens in page of doc_id 1412356: 13
# Number of tokens in page of doc_id 1412357: 16
# Number of tokens in page of doc_id 1412358: 13
# Number of tokens in page of doc_id 1412359: 13
# Number of tokens in page of doc_id 1412360: 13
# Number of tokens in page of doc_id 1412361: 15
# Number of tokens in page of doc_id 1412362: 13
# Number of tokens in page of doc_id 1412363: 13
# Number of tokens in page of doc_id 1412364: 13
# Number of tokens in page of doc_id 1412365: 13
# Number of tokens in page of doc_id 1412366: 13
# Number of tokens in page of doc_id 1412367: 13
# Number of tokens in page of doc_id 1412368: 13
# Number of tokens in page of doc_id 1412370: 106
# Number of tokens in page of doc_id 1412372: 13
# Number of tokens in page of doc_id 1412373: 17
# Number of tokens in page of doc_id 1412375: 17
# Number of tokens in page of doc_id 1412376: 13
# Number of tokens in page of doc_id 1412377: 13
# Number of tokens in page of doc_id 1412378: 13
# Number of tokens in page of doc_id 1412379: 13
# Number of tokens in page of doc_id 1412380: 13
# Number of tokens in page of doc_id 1412381: 13
# Number of tokens in page of doc_id 1412382: 13
# Number of tokens in page of doc_id 1412383: 13
# Number of tokens in page of doc_id 1412384: 13
# Number of tokens in page of doc_id 1412385: 25
# Number of tokens in page of doc_id 1412386: 17
# Number of tokens in page of doc_id 1412388: 156
# Number of tokens in page of doc_id 1412390: 64
# Number of tokens in page of doc_id 1412392: 267
# Number of tokens in page of doc_id 1412393: 444
# Number of tokens in page of doc_id 1412395: 357
# Number of tokens in page of doc_id 1412397: 24
# Number of tokens in page of doc_id 1412398: 145
# Number of tokens in page of doc_id 1412401: 318
# Number of tokens in page of doc_id 1412406: 221
# Number of tokens in page of doc_id 1412411: 7
# Number of tokens in page of doc_id 1412421: 232
# Number of tokens in page of doc_id 1412423: 45
# Number of tokens in page of doc_id 1412424: 67
# Number of tokens in page of doc_id 1412425: 979
# Number of tokens in page of doc_id 1412426: 177
# Number of tokens in page of doc_id 1412427: 399
# Number of tokens in page of doc_id 1412429: 261
# Number of tokens in page of doc_id 1412431: 196
# Number of tokens in page of doc_id 1412432: 45
# Number of tokens in page of doc_id 1412433: 306
# Number of tokens in page of doc_id 1412434: 93
# Number of tokens in page of doc_id 1412436: 103
# Number of tokens in page of doc_id 1412437: 172
# Number of tokens in page of doc_id 1412439: 44
# Number of tokens in page of doc_id 1412441: 30
# Number of tokens in page of doc_id 1412444: 8
# Number of tokens in page of doc_id 1412447: 156
# Number of tokens in page of doc_id 1412448: 21
# Number of tokens in page of doc_id 1412449: 277
# Number of tokens in page of doc_id 1412450: 35
# Number of tokens in page of doc_id 1412451: 481
# Number of tokens in page of doc_id 1412457: 101
# Number of tokens in page of doc_id 1412463: 34
# Number of tokens in page of doc_id 1412466: 85
# Number of tokens in page of doc_id 1412467: 111
# Number of tokens in page of doc_id 1412471: 61
# Number of tokens in page of doc_id 1412472: 177
# Number of tokens in page of doc_id 1412473: 81
# Number of tokens in page of doc_id 1412474: 15
# Number of tokens in page of doc_id 1412477: 15
# Number of tokens in page of doc_id 1412478: 154
# Number of tokens in page of doc_id 1412480: 14
# Number of tokens in page of doc_id 1412486: 15
# Number of tokens in page of doc_id 1412490: 15
# Number of tokens in page of doc_id 1412494: 39
# Number of tokens in page of doc_id 1412495: 13
# Number of tokens in page of doc_id 1412496: 13
# Number of tokens in page of doc_id 1412497: 13
# Number of tokens in page of doc_id 1412499: 13
# Number of tokens in page of doc_id 1412501: 13
# Number of tokens in page of doc_id 1412502: 13
# Number of tokens in page of doc_id 1412503: 13
# Number of tokens in page of doc_id 1412505: 13
# Number of tokens in page of doc_id 1412508: 15
# Number of tokens in page of doc_id 1412509: 31
# Number of tokens in page of doc_id 1412511: 15
# Number of tokens in page of doc_id 1412512: 15
# Number of tokens in page of doc_id 1412513: 15
# Number of tokens in page of doc_id 1412514: 39
# Number of tokens in page of doc_id 1412515: 5
# Number of tokens in page of doc_id 1412519: 83
# Number of tokens in page of doc_id 1412524: 91
# Number of tokens in page of doc_id 1412531: 94
# Number of tokens in page of doc_id 1412535: 75
# Number of tokens in page of doc_id 1412538: 24
# Number of tokens in page of doc_id 1412544: 26
# Number of tokens in page of doc_id 1412548: 38
# Number of tokens in page of doc_id 1412552: 27
# Number of tokens in page of doc_id 1412554: 19
# Number of tokens in page of doc_id 1412558: 17
# Number of tokens in page of doc_id 1412559: 85
# Number of tokens in page of doc_id 1412560: 30
# Number of tokens in page of doc_id 1412563: 39
# Number of tokens in page of doc_id 1412565: 24
# Number of tokens in page of doc_id 1412567: 15
# Number of tokens in page of doc_id 1412568: 15
# Number of tokens in page of doc_id 1412569: 199
# Number of tokens in page of doc_id 1412570: 15
# Number of tokens in page of doc_id 1412571: 15
# Number of tokens in page of doc_id 1412572: 15
# Number of tokens in page of doc_id 1412574: 15
# Number of tokens in page of doc_id 1412575: 26
# Number of tokens in page of doc_id 1412578: 15
# Number of tokens in page of doc_id 1412580: 15
# Number of tokens in page of doc_id 1412581: 22
# Number of tokens in page of doc_id 1412584: 202
# Number of tokens in page of doc_id 1412586: 15
# Number of tokens in page of doc_id 1412587: 104
# Number of tokens in page of doc_id 1412591: 15
# Number of tokens in page of doc_id 1412592: 15
# Number of tokens in page of doc_id 1412593: 27
# Number of tokens in page of doc_id 1412597: 162
# Number of tokens in page of doc_id 1412598: 158
# Number of tokens in page of doc_id 1412603: 79
# Number of tokens in page of doc_id 1412605: 54
# Number of tokens in page of doc_id 1412606: 230
# Number of tokens in page of doc_id 1412607: 664
# Number of tokens in page of doc_id 1412608: 117
# Number of tokens in page of doc_id 1412609: 15
# Number of tokens in page of doc_id 1412610: 15
# Number of tokens in page of doc_id 1412611: 15
# Number of tokens in page of doc_id 1412612: 15
# Number of tokens in page of doc_id 1412613: 15
# Number of tokens in page of doc_id 1412614: 15
# Number of tokens in page of doc_id 1412615: 15
# Number of tokens in page of doc_id 1412616: 15
# Number of tokens in page of doc_id 1412617: 15
# Number of tokens in page of doc_id 1412618: 15
# Number of tokens in page of doc_id 1412619: 15
# Number of tokens in page of doc_id 1412620: 15
# Number of tokens in page of doc_id 1412621: 15
# Number of tokens in page of doc_id 1412622: 15
# Number of tokens in page of doc_id 1412623: 15
# Number of tokens in page of doc_id 1412624: 15
# Number of tokens in page of doc_id 1412625: 15
# Number of tokens in page of doc_id 1412626: 15
# Number of tokens in page of doc_id 1412627: 15
# Number of tokens in page of doc_id 1412628: 177
# Number of tokens in page of doc_id 1412630: 33
# Number of tokens in page of doc_id 1412634: 59
# Number of tokens in page of doc_id 1412636: 28
# Number of tokens in page of doc_id 1412638: 20
# Number of tokens in page of doc_id 1412641: 21
# Number of tokens in page of doc_id 1412645: 29
# Number of tokens in page of doc_id 1412649: 21
# Number of tokens in page of doc_id 1412652: 35
# Number of tokens in page of doc_id 1412653: 28
# Number of tokens in page of doc_id 1412654: 124
# Number of tokens in page of doc_id 1412662: 47
# Number of tokens in page of doc_id 1412675: 47
# Number of tokens in page of doc_id 1412677: 27
# Number of tokens in page of doc_id 1412682: 35
# Number of tokens in page of doc_id 1412689: 28
# Number of tokens in page of doc_id 1412692: 110
# Number of tokens in page of doc_id 1412695: 16
# Number of tokens in page of doc_id 1412696: 57
# Number of tokens in page of doc_id 1412697: 319
# Number of tokens in page of doc_id 1412701: 16
# Number of tokens in page of doc_id 1412702: 82
# Number of tokens in page of doc_id 1412704: 14
# Number of tokens in page of doc_id 1412705: 46
# Number of tokens in page of doc_id 1412706: 82
# Number of tokens in page of doc_id 1412712: 107
# Number of tokens in page of doc_id 1412718: 195
# Number of tokens in page of doc_id 1412721: 494
# Number of tokens in page of doc_id 1412723: 56
# Number of tokens in page of doc_id 1412725: 41
# Number of tokens in page of doc_id 1412727: 240
# Number of tokens in page of doc_id 1412728: 107
# Number of tokens in page of doc_id 1412736: 29
# Number of tokens in page of doc_id 1412740: 368
# Number of tokens in page of doc_id 1412742: 9
# Number of tokens in page of doc_id 1412743: 121
# Number of tokens in page of doc_id 1412747: 71
# Number of tokens in page of doc_id 1412748: 281
# Number of tokens in page of doc_id 1412750: 269
# Number of tokens in page of doc_id 1412760: 211
# Number of tokens in page of doc_id 1412763: 315
# Number of tokens in page of doc_id 1412770: 89
# Number of tokens in page of doc_id 1412778: 235
# Number of tokens in page of doc_id 1412781: 147
# Number of tokens in page of doc_id 1412793: 78
# Number of tokens in page of doc_id 1412804: 19
# Number of tokens in page of doc_id 1412806: 28
# Number of tokens in page of doc_id 1412820: 39
# Number of tokens in page of doc_id 1412829: 37
# Number of tokens in page of doc_id 1412830: 160
# Number of tokens in page of doc_id 1412833: 25
# Number of tokens in page of doc_id 1412836: 15
# Number of tokens in page of doc_id 1412841: 333
# Number of tokens in page of doc_id 1412846: 198
# Number of tokens in page of doc_id 1412851: 156
# Number of tokens in page of doc_id 1412854: 1433
# Number of tokens in page of doc_id 1412857: 59
# Number of tokens in page of doc_id 1412860: 314
# Number of tokens in page of doc_id 1412865: 71
# Number of tokens in page of doc_id 1412866: 129
# Number of tokens in page of doc_id 1412870: 169
# Number of tokens in page of doc_id 1412873: 603
# Number of tokens in page of doc_id 1412875: 102
# Number of tokens in page of doc_id 1412877: 227
# Number of tokens in page of doc_id 1412878: 230
# Number of tokens in page of doc_id 1412879: 23
# Number of tokens in page of doc_id 1412882: 259
# Number of tokens in page of doc_id 1412885: 90
# Number of tokens in page of doc_id 1412888: 148
# Number of tokens in page of doc_id 1412895: 49
# Number of tokens in page of doc_id 1412899: 130
# Number of tokens in page of doc_id 1412901: 34
# Number of tokens in page of doc_id 1412907: 65
# Number of tokens in page of doc_id 1412914: 44
# Number of tokens in page of doc_id 1412916: 47
# Number of tokens in page of doc_id 1412921: 11
# Number of tokens in page of doc_id 1412922: 205
# Number of tokens in page of doc_id 1412923: 58
# Number of tokens in page of doc_id 1412930: 47
# Number of tokens in page of doc_id 1412939: 571
# Number of tokens in page of doc_id 1412943: 237
# Number of tokens in page of doc_id 1412951: 132
# Number of tokens in page of doc_id 1412962: 162
# Number of tokens in page of doc_id 1412964: 77
# Number of tokens in page of doc_id 1412965: 162
# Number of tokens in page of doc_id 1412969: 34
# Number of tokens in page of doc_id 1412970: 248
# Number of tokens in page of doc_id 1412972: 52
# Number of tokens in page of doc_id 1412973: 72
# Number of tokens in page of doc_id 1412974: 13
# Number of tokens in page of doc_id 1412975: 128
# Number of tokens in page of doc_id 1412977: 8
# Number of tokens in page of doc_id 1412990: 167
# Number of tokens in page of doc_id 1412994: 55
# Number of tokens in page of doc_id 1412995: 84
# Number of tokens in page of doc_id 1412996: 59
# Number of tokens in page of doc_id 1412997: 290
# Number of tokens in page of doc_id 1412998: 47
# Number of tokens in page of doc_id 1413000: 104
# Number of tokens in page of doc_id 1413001: 201
# Number of tokens in page of doc_id 1413011: 336
# Number of tokens in page of doc_id 1413021: 106
# Number of tokens in page of doc_id 1413022: 7
# Number of tokens in page of doc_id 1413023: 192
# Number of tokens in page of doc_id 1413026: 239
# Number of tokens in page of doc_id 1413028: 84
# Number of tokens in page of doc_id 1413033: 69
# Number of tokens in page of doc_id 1413035: 53
# Number of tokens in page of doc_id 1413039: 116
# Number of tokens in page of doc_id 1413043: 110
# Number of tokens in page of doc_id 1413049: 154
# Number of tokens in page of doc_id 1413050: 79
# Number of tokens in page of doc_id 1413055: 48
# Number of tokens in page of doc_id 1413056: 106
# Number of tokens in page of doc_id 1413059: 34
# Number of tokens in page of doc_id 1413067: 849
# Number of tokens in page of doc_id 1413069: 25
# Number of tokens in page of doc_id 1413070: 21
# Number of tokens in page of doc_id 1413074: 13
# Number of tokens in page of doc_id 1413076: 13
# Number of tokens in page of doc_id 1413078: 13
# Number of tokens in page of doc_id 1413079: 13
# Number of tokens in page of doc_id 1413080: 28
# Number of tokens in page of doc_id 1413082: 13
# Number of tokens in page of doc_id 1413083: 13
# Number of tokens in page of doc_id 1413084: 13
# Number of tokens in page of doc_id 1413085: 13
# Number of tokens in page of doc_id 1413086: 13
# Number of tokens in page of doc_id 1413087: 13
# Number of tokens in page of doc_id 1413088: 13
# Number of tokens in page of doc_id 1413089: 13
# Number of tokens in page of doc_id 1413092: 42
# Number of tokens in page of doc_id 1413095: 25
# Number of tokens in page of doc_id 1413098: 41
# Number of tokens in page of doc_id 1413099: 46
# Number of tokens in page of doc_id 1413102: 17
# Number of tokens in page of doc_id 1413103: 15
# Number of tokens in page of doc_id 1413104: 15
# Number of tokens in page of doc_id 1413105: 31
# Number of tokens in page of doc_id 1413106: 15
# Number of tokens in page of doc_id 1413107: 29
# Number of tokens in page of doc_id 1413108: 15
# Number of tokens in page of doc_id 1413109: 15
# Number of tokens in page of doc_id 1413110: 15
# Number of tokens in page of doc_id 1413112: 27
# Number of tokens in page of doc_id 1413115: 14
# Number of tokens in page of doc_id 1413117: 15
# Number of tokens in page of doc_id 1413119: 15
# Number of tokens in page of doc_id 1413120: 40
# Number of tokens in page of doc_id 1413121: 15
# Number of tokens in page of doc_id 1413122: 15
# Number of tokens in page of doc_id 1413123: 403
# Number of tokens in page of doc_id 1413124: 127
# Number of tokens in page of doc_id 1413125: 15
# Number of tokens in page of doc_id 1413129: 93
# Number of tokens in page of doc_id 1413131: 211
# Number of tokens in page of doc_id 1413132: 123
# Number of tokens in page of doc_id 1413133: 35
# Number of tokens in page of doc_id 1413135: 42
# Number of tokens in page of doc_id 1413138: 112
# Number of tokens in page of doc_id 1413140: 51
# Number of tokens in page of doc_id 1413142: 78
# Number of tokens in page of doc_id 1413145: 174
# Number of tokens in page of doc_id 1413146: 200
# Number of tokens in page of doc_id 1413149: 97
# Number of tokens in page of doc_id 1413150: 97
# Number of tokens in page of doc_id 1413151: 101
# Number of tokens in page of doc_id 1413152: 477
# Number of tokens in page of doc_id 1413155: 103
# Number of tokens in page of doc_id 1413158: 235
# Number of tokens in page of doc_id 1413161: 67
# Number of tokens in page of doc_id 1413163: 8
# Number of tokens in page of doc_id 1413164: 56
# Number of tokens in page of doc_id 1413165: 743
# Number of tokens in page of doc_id 1413167: 160
# Number of tokens in page of doc_id 1413168: 415
# Number of tokens in page of doc_id 1413169: 203
# Number of tokens in page of doc_id 1413172: 57
# Number of tokens in page of doc_id 1413173: 50
# Number of tokens in page of doc_id 1413175: 273
# Number of tokens in page of doc_id 1413180: 143
# Number of tokens in page of doc_id 1413185: 300
# Number of tokens in page of doc_id 1413186: 10
# Number of tokens in page of doc_id 1413187: 94
# Number of tokens in page of doc_id 1413193: 155
# Number of tokens in page of doc_id 1413198: 435
# Number of tokens in page of doc_id 1413199: 49
# Number of tokens in page of doc_id 1413202: 166
# Number of tokens in page of doc_id 1413205: 32
# Number of tokens in page of doc_id 1413208: 199
# Number of tokens in page of doc_id 1413209: 151
# Number of tokens in page of doc_id 1413214: 35
# Number of tokens in page of doc_id 1413216: 42
# Number of tokens in page of doc_id 1413219: 72
# Number of tokens in page of doc_id 1413220: 136
# Number of tokens in page of doc_id 1413221: 118
# Number of tokens in page of doc_id 1413222: 39
# Number of tokens in page of doc_id 1413224: 123
# Number of tokens in page of doc_id 1413226: 8
# Number of tokens in page of doc_id 1413227: 45
# Number of tokens in page of doc_id 1413232: 224
# Number of tokens in page of doc_id 1413233: 49
# Number of tokens in page of doc_id 1413236: 36
# Number of tokens in page of doc_id 1413238: 78
# Number of tokens in page of doc_id 1413239: 97
# Number of tokens in page of doc_id 1413241: 41
# Number of tokens in page of doc_id 1413246: 36
# Number of tokens in page of doc_id 1413247: 30
# Number of tokens in page of doc_id 1413249: 21
# Number of tokens in page of doc_id 1413258: 30
# Number of tokens in page of doc_id 1413264: 23
# Number of tokens in page of doc_id 1413273: 82
# Number of tokens in page of doc_id 1413274: 26
# Number of tokens in page of doc_id 1413275: 71
# Number of tokens in page of doc_id 1413276: 29
# Number of tokens in page of doc_id 1413278: 98
# Number of tokens in page of doc_id 1413282: 173
# Number of tokens in page of doc_id 1413286: 8
# Number of tokens in page of doc_id 1413288: 72
# Number of tokens in page of doc_id 1413292: 8
# Number of tokens in page of doc_id 1413297: 48
# Number of tokens in page of doc_id 1413298: 23
# Number of tokens in page of doc_id 1413300: 54
# Number of tokens in page of doc_id 1413303: 8
# Number of tokens in page of doc_id 1413307: 38
# Number of tokens in page of doc_id 1413309: 195
# Number of tokens in page of doc_id 1413310: 37
# Number of tokens in page of doc_id 1413312: 197
# Number of tokens in page of doc_id 1413314: 57
# Number of tokens in page of doc_id 1413315: 119
# Number of tokens in page of doc_id 1413322: 166
# Number of tokens in page of doc_id 1413323: 202
# Number of tokens in page of doc_id 1413324: 148
# Number of tokens in page of doc_id 1413328: 47
# Number of tokens in page of doc_id 1413329: 33
# Number of tokens in page of doc_id 1413332: 98
# Number of tokens in page of doc_id 1413339: 61
# Number of tokens in page of doc_id 1413344: 46
# Number of tokens in page of doc_id 1413351: 132
# Number of tokens in page of doc_id 1413355: 171
# Number of tokens in page of doc_id 1413360: 67
# Number of tokens in page of doc_id 1413363: 47
# Number of tokens in page of doc_id 1413364: 391
# Number of tokens in page of doc_id 1413366: 102
# Number of tokens in page of doc_id 1413368: 177
# Number of tokens in page of doc_id 1413369: 48
# Number of tokens in page of doc_id 1413371: 81
# Number of tokens in page of doc_id 1413373: 99
# Number of tokens in page of doc_id 1413380: 13
# Number of tokens in page of doc_id 1413381: 60
# Number of tokens in page of doc_id 1413386: 763
# Number of tokens in page of doc_id 1413391: 9
# Number of tokens in page of doc_id 1413392: 120
# Number of tokens in page of doc_id 1413395: 13
# Number of tokens in page of doc_id 1413406: 219
# Number of tokens in page of doc_id 1413421: 29
# Number of tokens in page of doc_id 1413460: 25
# Number of tokens in page of doc_id 1413473: 264
# Number of tokens in page of doc_id 1413484: 52
# Number of tokens in page of doc_id 1413486: 27
# Number of tokens in page of doc_id 1413487: 136
# Number of tokens in page of doc_id 1413490: 26
# Number of tokens in page of doc_id 1413491: 18
# Number of tokens in page of doc_id 1413501: 37
# Number of tokens in page of doc_id 1413505: 21
# Number of tokens in page of doc_id 1413521: 10
# Number of tokens in page of doc_id 1413523: 15
# Number of tokens in page of doc_id 1413524: 154
# Number of tokens in page of doc_id 1413526: 84
# Number of tokens in page of doc_id 1413535: 113
# Number of tokens in page of doc_id 1413547: 13
# Number of tokens in page of doc_id 1413548: 13
# Number of tokens in page of doc_id 1413549: 43
# Number of tokens in page of doc_id 1413550: 670
# Number of tokens in page of doc_id 1413551: 35
# Number of tokens in page of doc_id 1413553: 96
# Number of tokens in page of doc_id 1413554: 39
# Number of tokens in page of doc_id 1413557: 49
# Number of tokens in page of doc_id 1413566: 55
# Number of tokens in page of doc_id 1413569: 92
# Number of tokens in page of doc_id 1413571: 97
# Number of tokens in page of doc_id 1413580: 457
# Number of tokens in page of doc_id 1413581: 6
# Number of tokens in page of doc_id 1413582: 121
# Number of tokens in page of doc_id 1413584: 56
# Number of tokens in page of doc_id 1413587: 54
# Number of tokens in page of doc_id 1413588: 68
# Number of tokens in page of doc_id 1413591: 24
# Number of tokens in page of doc_id 1413601: 80
# ...
# Number of tokens in page of doc_id 1424279: 55
# Number of tokens in page of doc_id 1424280: 324
# Number of tokens in page of doc_id 1424281: 379
# Number of tokens in page of doc_id 1424285: 142
# Number of tokens in page of doc_id 1424286: 108
# Number of tokens in page of doc_id 1424287: 54
# Number of tokens in page of doc_id 1424289: 31
# Number of tokens in page of doc_id 1424290: 35
# Number of tokens in page of doc_id 1424295: 32
# Number of tokens in page of doc_id 1424298: 205
# Number of tokens in page of doc_id 1424299: 96
# Number of tokens in page of doc_id 1424300: 411
# Number of tokens in page of doc_id 1424303: 53
# Number of tokens in page of doc_id 1424304: 76
# Number of tokens in page of doc_id 1424307: 23
# Number of tokens in page of doc_id 1424308: 440
# Number of tokens in page of doc_id 1424310: 265
# Number of tokens in page of doc_id 1424311: 29
# Number of tokens in page of doc_id 1424314: 51
# Number of tokens in page of doc_id 1424316: 130
# Number of tokens in page of doc_id 1424317: 282
# Number of tokens in page of doc_id 1424320: 23
# Number of tokens in page of doc_id 1424321: 87
# Number of tokens in page of doc_id 1424322: 520
# Number of tokens in page of doc_id 1424323: 23
# Number of tokens in page of doc_id 1424325: 56
# Number of tokens in page of doc_id 1424326: 61
# Number of tokens in page of doc_id 1424327: 341
# Number of tokens in page of doc_id 1424330: 260
# Number of tokens in page of doc_id 1424333: 95
# Number of tokens in page of doc_id 1424339: 51
# Number of tokens in page of doc_id 1424344: 24
# Number of tokens in page of doc_id 1424345: 24
# Number of tokens in page of doc_id 1424347: 112
# Number of tokens in page of doc_id 1424348: 298
# Number of tokens in page of doc_id 1424350: 24
# Number of tokens in page of doc_id 1424352: 142
# Number of tokens in page of doc_id 1424353: 158
# Number of tokens in page of doc_id 1424354: 38
# Number of tokens in page of doc_id 1424360: 133
# Number of tokens in page of doc_id 1424362: 97
# Number of tokens in page of doc_id 1424365: 61
# Number of tokens in page of doc_id 1424367: 119
# Number of tokens in page of doc_id 1424369: 114
# Number of tokens in page of doc_id 1424372: 34
# Number of tokens in page of doc_id 1424374: 114
# Number of tokens in page of doc_id 1424375: 43
# Number of tokens in page of doc_id 1424378: 166
# Number of tokens in page of doc_id 1424379: 100
# Number of tokens in page of doc_id 1424384: 84
# Number of tokens in page of doc_id 1424385: 175
# Number of tokens in page of doc_id 1424397: 917
# Number of tokens in page of doc_id 1424402: 24
# Number of tokens in page of doc_id 1424403: 93
# Number of tokens in page of doc_id 1424406: 224
# Number of tokens in page of doc_id 1424408: 86
# Number of tokens in page of doc_id 1424412: 33
# Number of tokens in page of doc_id 1424413: 161
# Number of tokens in page of doc_id 1424416: 146
# Number of tokens in page of doc_id 1424419: 242
# Number of tokens in page of doc_id 1424422: 44
# Number of tokens in page of doc_id 1424429: 45
# Number of tokens in page of doc_id 1424430: 79
# Number of tokens in page of doc_id 1424433: 32
# Number of tokens in page of doc_id 1424435: 59
# Number of tokens in page of doc_id 1424440: 184
# Number of tokens in page of doc_id 1424445: 96
# Number of tokens in page of doc_id 1424446: 776
# Number of tokens in page of doc_id 1424453: 157
# Number of tokens in page of doc_id 1424455: 127
# Number of tokens in page of doc_id 1424457: 139
# Number of tokens in page of doc_id 1424458: 253
# Number of tokens in page of doc_id 1424462: 69
# Number of tokens in page of doc_id 1424464: 74
# Number of tokens in page of doc_id 1424465: 213
# Number of tokens in page of doc_id 1424469: 56
# Number of tokens in page of doc_id 1424473: 314
# Number of tokens in page of doc_id 1424474: 60
# Number of tokens in page of doc_id 1424477: 411
# Number of tokens in page of doc_id 1424478: 23
# Number of tokens in page of doc_id 1424479: 76
# Number of tokens in page of doc_id 1424480: 88
# Number of tokens in page of doc_id 1424482: 52
# Number of tokens in page of doc_id 1424483: 102
# Number of tokens in page of doc_id 1424485: 58
# Number of tokens in page of doc_id 1424487: 68
# Number of tokens in page of doc_id 1424490: 86
# Number of tokens in page of doc_id 1424492: 40
# Number of tokens in page of doc_id 1424493: 179
# Number of tokens in page of doc_id 1424498: 543
# Number of tokens in page of doc_id 1424501: 88
# Number of tokens in page of doc_id 1424504: 94
# Number of tokens in page of doc_id 1424506: 158
# Number of tokens in page of doc_id 1424507: 551
# Number of tokens in page of doc_id 1424511: 43
# Number of tokens in page of doc_id 1424513: 228
# Number of tokens in page of doc_id 1424515: 298
# Number of tokens in page of doc_id 1424516: 301
# Number of tokens in page of doc_id 1424526: 142
# Number of tokens in page of doc_id 1424529: 144
# Number of tokens in page of doc_id 1424531: 5
# Number of tokens in page of doc_id 1424533: 23
# Number of tokens in page of doc_id 1424535: 23
# Number of tokens in page of doc_id 1424537: 339
# Number of tokens in page of doc_id 1424540: 29
# Number of tokens in page of doc_id 1424545: 75
# Number of tokens in page of doc_id 1424546: 38
# Number of tokens in page of doc_id 1424552: 536
# Number of tokens in page of doc_id 1424559: 140
# Number of tokens in page of doc_id 1424563: 54
# Number of tokens in page of doc_id 1424567: 141
# Number of tokens in page of doc_id 1424568: 87
# Number of tokens in page of doc_id 1424577: 66
# Number of tokens in page of doc_id 1424580: 23
# Number of tokens in page of doc_id 1424582: 490
# Number of tokens in page of doc_id 1424590: 50
# Number of tokens in page of doc_id 1424594: 78
# Number of tokens in page of doc_id 1424595: 22
# Number of tokens in page of doc_id 1424600: 23
# Number of tokens in page of doc_id 1424601: 435
# Number of tokens in page of doc_id 1424603: 605
# Number of tokens in page of doc_id 1424606: 39
# Number of tokens in page of doc_id 1424607: 131
# Number of tokens in page of doc_id 1424608: 49
# Number of tokens in page of doc_id 1424610: 228
# Number of tokens in page of doc_id 1424612: 39
# Number of tokens in page of doc_id 1424617: 47
# Number of tokens in page of doc_id 1424618: 84
# Number of tokens in page of doc_id 1424619: 88
# Number of tokens in page of doc_id 1424620: 320
# Number of tokens in page of doc_id 1424624: 39
# Number of tokens in page of doc_id 1424626: 110
# Number of tokens in page of doc_id 1424627: 70
# Number of tokens in page of doc_id 1424632: 267
# Number of tokens in page of doc_id 1424634: 30
# Number of tokens in page of doc_id 1424642: 54
# Number of tokens in page of doc_id 1424645: 133
# Number of tokens in page of doc_id 1424646: 14
# Number of tokens in page of doc_id 1424649: 43
# Number of tokens in page of doc_id 1424650: 143
# Number of tokens in page of doc_id 1424654: 106
# Number of tokens in page of doc_id 1424655: 109
# Number of tokens in page of doc_id 1424657: 13
# Number of tokens in page of doc_id 1424658: 185
# Number of tokens in page of doc_id 1424663: 137
# Number of tokens in page of doc_id 1424667: 10
# Number of tokens in page of doc_id 1424669: 23
# Number of tokens in page of doc_id 1424677: 11
# Number of tokens in page of doc_id 1424679: 23
# Number of tokens in page of doc_id 1424680: 185
# Number of tokens in page of doc_id 1424682: 50
# Number of tokens in page of doc_id 1424685: 58
# Number of tokens in page of doc_id 1424686: 355
# Number of tokens in page of doc_id 1424687: 250
# Number of tokens in page of doc_id 1424688: 46
# Number of tokens in page of doc_id 1424689: 386
# Number of tokens in page of doc_id 1424691: 213
# Number of tokens in page of doc_id 1424699: 156
# Number of tokens in page of doc_id 1424700: 74
# Number of tokens in page of doc_id 1424705: 23
# Number of tokens in page of doc_id 1424707: 132
# Number of tokens in page of doc_id 1424709: 1145
# Number of tokens in page of doc_id 1424710: 118
# Number of tokens in page of doc_id 1424713: 22
# Number of tokens in page of doc_id 1424714: 150
# Number of tokens in page of doc_id 1424715: 23
# Number of tokens in page of doc_id 1424716: 23
# Number of tokens in page of doc_id 1424723: 185
# Number of tokens in page of doc_id 1424724: 596
# Number of tokens in page of doc_id 1424727: 137
# Number of tokens in page of doc_id 1424730: 479
# Number of tokens in page of doc_id 1424732: 56
# Number of tokens in page of doc_id 1424738: 134
# Number of tokens in page of doc_id 1424742: 174
# Number of tokens in page of doc_id 1424743: 444
# Number of tokens in page of doc_id 1424745: 59
# Number of tokens in page of doc_id 1424746: 13
# Number of tokens in page of doc_id 1424749: 176
# Number of tokens in page of doc_id 1424751: 23
# Number of tokens in page of doc_id 1424754: 21
# Number of tokens in page of doc_id 1424757: 119
# Number of tokens in page of doc_id 1424762: 56
# Number of tokens in page of doc_id 1424771: 23
# Number of tokens in page of doc_id 1424772: 57
# Number of tokens in page of doc_id 1424774: 81
# Number of tokens in page of doc_id 1424776: 241
# Number of tokens in page of doc_id 1424778: 100
# Number of tokens in page of doc_id 1424781: 162
# Number of tokens in page of doc_id 1424783: 81
# Number of tokens in page of doc_id 1424787: 136
# Number of tokens in page of doc_id 1424789: 23
# Number of tokens in page of doc_id 1424793: 138
# Number of tokens in page of doc_id 1424795: 50
# Number of tokens in page of doc_id 1424799: 137
# Number of tokens in page of doc_id 1424801: 158
# Number of tokens in page of doc_id 1424804: 136
# Number of tokens in page of doc_id 1424805: 84
# Number of tokens in page of doc_id 1424806: 23
# Number of tokens in page of doc_id 1424809: 104
# Number of tokens in page of doc_id 1424813: 23
# Number of tokens in page of doc_id 1424814: 55
# Number of tokens in page of doc_id 1424815: 298
# Number of tokens in page of doc_id 1424819: 23
# Number of tokens in page of doc_id 1424820: 514
# Number of tokens in page of doc_id 1424821: 287
# Number of tokens in page of doc_id 1424822: 111
# Number of tokens in page of doc_id 1424823: 71
# Number of tokens in page of doc_id 1424824: 89
# Number of tokens in page of doc_id 1424826: 68
# Number of tokens in page of doc_id 1424829: 75
# Number of tokens in page of doc_id 1424830: 61
# Number of tokens in page of doc_id 1424831: 67
# Number of tokens in page of doc_id 1424833: 204
# Number of tokens in page of doc_id 1424834: 23
# Number of tokens in page of doc_id 1424835: 101
# Number of tokens in page of doc_id 1424836: 293
# Number of tokens in page of doc_id 1424838: 23
# Number of tokens in page of doc_id 1424840: 82
# Number of tokens in page of doc_id 1424841: 64
# Number of tokens in page of doc_id 1424842: 34
# Number of tokens in page of doc_id 1424844: 43
# Number of tokens in page of doc_id 1424845: 67
# Number of tokens in page of doc_id 1424846: 42
# Number of tokens in page of doc_id 1424850: 203
# Number of tokens in page of doc_id 1424852: 99
# Number of tokens in page of doc_id 1424855: 145
# Number of tokens in page of doc_id 1424856: 23
# Number of tokens in page of doc_id 1424857: 12
# Number of tokens in page of doc_id 1424858: 23
# Number of tokens in page of doc_id 1424862: 162
# Number of tokens in page of doc_id 1424863: 73
# Number of tokens in page of doc_id 1424866: 119
# Number of tokens in page of doc_id 1424867: 26
# Number of tokens in page of doc_id 1424868: 52
# Number of tokens in page of doc_id 1424870: 22
# Number of tokens in page of doc_id 1424872: 44
# Number of tokens in page of doc_id 1424873: 27
# Number of tokens in page of doc_id 1424877: 171
# Number of tokens in page of doc_id 1424880: 61
# Number of tokens in page of doc_id 1424882: 34
# Number of tokens in page of doc_id 1424884: 23
# Number of tokens in page of doc_id 1424891: 62
# Number of tokens in page of doc_id 1424893: 36
# Number of tokens in page of doc_id 1424894: 504
# Number of tokens in page of doc_id 1424895: 51
# Number of tokens in page of doc_id 1424897: 221
# Number of tokens in page of doc_id 1424905: 23
# Number of tokens in page of doc_id 1424906: 23
# Number of tokens in page of doc_id 1424907: 31
# Number of tokens in page of doc_id 1424908: 23
# Number of tokens in page of doc_id 1424909: 33
# Number of tokens in page of doc_id 1424910: 42
# Number of tokens in page of doc_id 1424912: 83
# Number of tokens in page of doc_id 1424914: 36
# Number of tokens in page of doc_id 1424924: 47
# Number of tokens in page of doc_id 1424925: 23
# Number of tokens in page of doc_id 1424929: 79
# Number of tokens in page of doc_id 1424930: 128
# Number of tokens in page of doc_id 1424932: 164
# Number of tokens in page of doc_id 1424933: 136
# Number of tokens in page of doc_id 1424937: 135
# Number of tokens in page of doc_id 1424938: 139
# Number of tokens in page of doc_id 1424940: 517
# Number of tokens in page of doc_id 1424941: 26
# Number of tokens in page of doc_id 1424947: 23
# Number of tokens in page of doc_id 1424949: 23
# Number of tokens in page of doc_id 1424950: 78
# Number of tokens in page of doc_id 1424951: 23
# Number of tokens in page of doc_id 1424952: 23
# Number of tokens in page of doc_id 1424953: 23
# Number of tokens in page of doc_id 1424954: 23
# Number of tokens in page of doc_id 1424955: 23
# Number of tokens in page of doc_id 1424956: 23
# Number of tokens in page of doc_id 1424957: 23
# Number of tokens in page of doc_id 1424958: 23
# Number of tokens in page of doc_id 1424961: 23
# Number of tokens in page of doc_id 1424962: 31
# Number of tokens in page of doc_id 1424965: 172
# Number of tokens in page of doc_id 1424967: 759
# Number of tokens in page of doc_id 1424971: 16
# Number of tokens in page of doc_id 1424972: 31
# Number of tokens in page of doc_id 1424973: 26
# Number of tokens in page of doc_id 1424974: 72
# Number of tokens in page of doc_id 1424981: 52
# Number of tokens in page of doc_id 1424987: 66
# Number of tokens in page of doc_id 1424989: 64
# Number of tokens in page of doc_id 1424992: 57
# Number of tokens in page of doc_id 1424998: 227
# Number of tokens in page of doc_id 1425000: 120
# Number of tokens in page of doc_id 1425001: 15
# Number of tokens in page of doc_id 1425002: 364
# Number of tokens in page of doc_id 1425008: 34
# Number of tokens in page of doc_id 1425014: 91
# Number of tokens in page of doc_id 1425015: 28
# Number of tokens in page of doc_id 1425016: 303
# Number of tokens in page of doc_id 1425018: 49
# Number of tokens in page of doc_id 1425022: 67
# Number of tokens in page of doc_id 1425024: 13
# Number of tokens in page of doc_id 1425029: 15
# Number of tokens in page of doc_id 1425031: 79
# Number of tokens in page of doc_id 1425032: 14
# Number of tokens in page of doc_id 1425033: 13
# Number of tokens in page of doc_id 1425034: 87
# Number of tokens in page of doc_id 1425037: 139
# Number of tokens in page of doc_id 1425041: 114
# Number of tokens in page of doc_id 1425044: 70
# Number of tokens in page of doc_id 1425045: 59
# Number of tokens in page of doc_id 1425046: 475
# Number of tokens in page of doc_id 1425049: 110
# Number of tokens in page of doc_id 1425054: 34
# Number of tokens in page of doc_id 1425055: 47
# Number of tokens in page of doc_id 1425057: 23
# Number of tokens in page of doc_id 1425064: 1612
# Number of tokens in page of doc_id 1425066: 63
# Number of tokens in page of doc_id 1425075: 78
# Number of tokens in page of doc_id 1425078: 161
# Number of tokens in page of doc_id 1425080: 68
# Number of tokens in page of doc_id 1425081: 144
# Number of tokens in page of doc_id 1425084: 513
# Number of tokens in page of doc_id 1425085: 30
# Number of tokens in page of doc_id 1425087: 66
# Number of tokens in page of doc_id 1425093: 161
# Number of tokens in page of doc_id 1425094: 46
# Number of tokens in page of doc_id 1425095: 29
# Number of tokens in page of doc_id 1425096: 119
# Number of tokens in page of doc_id 1425099: 90
# Number of tokens in page of doc_id 1425101: 36
# Number of tokens in page of doc_id 1425103: 51
# Number of tokens in page of doc_id 1425111: 45
# Number of tokens in page of doc_id 1425116: 193
# Number of tokens in page of doc_id 1425118: 137
# Number of tokens in page of doc_id 1425120: 91
# Number of tokens in page of doc_id 1425122: 102
# Number of tokens in page of doc_id 1425128: 124
# Number of tokens in page of doc_id 1425129: 42
# Number of tokens in page of doc_id 1425130: 101
# Number of tokens in page of doc_id 1425137: 93

# %%
# min, max, and bins
min = vc.min()
max = vc.max()
print(f"Minimum Number of Tokens observed on a Page: {min}")
print(f"Maximum Number of Tokens observed on a Page: {max}")
bins = 20
edges = np.linspace(0, max, bins+1)
div = pd.cut(vc, bins=edges)
bin_counts = div.value_counts().sort_index()

freq = np.sort(bin_counts.values)[::-1]
ranks = np.arange(1, len(freq) + 1)

plt.figure(figsize=(10,6))
plt.hist(vc.values, color="skyblue", bins=20) # or plt.bar(ranks, freq, alpha=0.5)
plt.xlabel("Rank")
plt.ylabel("Frequency")
plt.title("Histogram of Token Counts")
plt.show()
# Out:
# Minimum Number of Tokens observed on a Page: 1
# Maximum Number of Tokens observed on a Page: 32864

# %%
def fit_zipf(data, offset=False, title="Zipf\'s Law"):
    freq = np.sort(data)[::-1]
    # freq = freq[freq > 0]

    ranks = np.arange(1, len(freq) + 1)

    B = 0.1

    log_r = np.log10(ranks + B)
    if offset:
        log_L = np.log10(freq + 1) # baseline +1 to deal with 0 frequencies which would throw error
    else:
        log_L = np.log10(freq)

    slope, intercept, r, p, e = stats.linregress(log_r, log_L)
    alpha = -slope
    C = 10 ** intercept

    log_L_pred = intercept + slope * log_r

    n = len(log_r)
    t_val = stats.t.ppf(0.95, n - 2)
    s_yx = np.sqrt(np.sum((log_L - log_L_pred) ** 2) / (n - 2))
    mean_x = np.mean(log_r)
    conf = t_val * s_yx * np.sqrt(1/n + (log_r - mean_x)**2 / np.sum((log_r - mean_x)**2))

    upper = log_L_pred + conf
    lower = log_L_pred - conf

    r2 = r**2
    k = 1
    adj_r2 = 1 - (1 - r2) * (n - 1) / (n - k - 1)

    plt.figure(figsize=(10,6))
    plt.scatter(log_r, log_L, s=10, alpha=0.5, label="Observed frequencies")
    plt.plot(log_r, log_L_pred, "r", label="Linear fit")
    plt.fill_between(log_r, lower, upper, color="pink", alpha=0.3, label="90% conf. interval")
    plt.xlabel("log10(rank + B)")
    plt.ylabel("log10(freq)")
    plt.title(title)
    plt.legend()
    plt.show()

    # print(f"C = {C}")
    # print(f"alpha = {alpha}")

    outside = np.sum((log_L < lower) | (log_L > upper))
    percent_outside = 100 * outside / len(log_L)
    print(f"Observations outside 90% confidence bounds: {percent_outside}%")

    print(f"\nR^2 = {r2}")
    print(f"adjusted R^2 = {adj_r2}")

    if adj_r2 > 0.9:
        print("\nFits Zipf\'s law very well.")
    elif adj_r2 > 0.7:
        print("\nFits Zipf\'s law roughly.")
    else:
        print("\nDoes not fit Zipf\'s law well.")

# %%
# zipf fitting
fit_zipf(bin_counts.values, offset=True, title="Zipf\'s Law for Frequencies of Token-Counts over Wiki Pages")
# Out:
# Observations outside 90% confidence bounds: 65.0%
#
# R^2 = 0.9597822722885081
# adjusted R^2 = 0.9575479540823141
#
# Fits Zipf's law very well.

# %%
freq = np.sort(bin_counts.values)[::-1]
ranks = np.arange(1, len(freq) + 1)

def zipf_func(r, C, alpha, B):
    return C / np.power(r + B, alpha)

p0 = [freq.max(), 1.0, 0.1]
bounds = ([0, 0, 0], [np.inf, 10, np.inf])

popt, pcov = curve_fit(zipf_func, ranks, freq, p0=p0, bounds=bounds)
C_opt, alpha_opt, B_opt = popt

r_smooth = np.linspace(1, len(freq), 500)
fitted_curve = zipf_func(r_smooth, C_opt, alpha_opt, B_opt)

plt.figure(figsize=(10,6))
plt.bar(ranks, freq, alpha=0.5)
plt.plot(r_smooth, fitted_curve, 'r-', linewidth=2, label="Fitted Zipf curve")
plt.xlabel("Rank")
plt.ylabel("Frequency")
plt.title("Zipf Curve Fitted to Histogram")
plt.legend()
plt.show()

# %%
# Task 5 — Linked tokens per page (proxy = PROPN)

# The Finnish Wikipedia VRT files don’t include hyperlink markup, so we can’t count real clickable links.
# To stay consistent with the assignment, we approximate “linked tokens” with proper nouns (UPOS == 'PROPN'),
# since proper names are usually the ones that get linked in Wikipedia articles.

# If the token-level DataFrame isn't already in memory (from previous tasks), load the parquet we saved earlier.
if 'df' not in globals():
    df = pd.read_parquet("merged_corpus.parquet")

# Per-page totals
# - tokens_per_doc: total tokens in each page
# - linked_tokens_per_doc: count of PROPN tokens per page (our proxy for “linked tokens”)
tokens_per_doc = df.groupby('doc_id').size().astype(int)
linked_tokens_per_doc = (df['upos'].eq('PROPN')).groupby(df['doc_id']).sum().astype(int)

task5 = (
    pd.DataFrame({
        'tokens_per_doc': tokens_per_doc,
        'linked_tokens_per_doc': linked_tokens_per_doc
    })
    .reset_index()
    .rename(columns={'index': 'doc_id'})
)

print("Task 5 — per-page summary (first 5 rows):")
display(task5.head())
print(task5[['tokens_per_doc','linked_tokens_per_doc']].describe(percentiles=[0.1,0.5,0.9]))

# Build the 20-bin histogram for linked tokens per page (same min→max approach as Task 3)
vals = task5['linked_tokens_per_doc'].to_numpy()
vmin, vmax = int(vals.min()), int(vals.max())
bins = 20

hist, edges = np.histogram(vals, bins=bins, range=(vmin, vmax))

plt.hist(vals, bins=bins)
plt.xlabel("Linked tokens per page (PROPN count)")
plt.ylabel("Frequency")
plt.title("Task 5 — Histogram (20 bins) of linked tokens per page")
plt.show()

# Sometimes the skew is extreme and the head dominates. A log–log view makes the tail easier to see.
plt.hist(vals, bins=bins, log=True)
plt.xscale('log')
plt.xlabel("Linked tokens per page (log scale)")
plt.ylabel("Frequency (log scale)")
plt.title("Task 5 — Linked tokens per page (log–log view)")
plt.show()

# Zipf fit on histogram ranks (same idea as Task 3):
#   1) Sort bin frequencies in descending order → rank = 1..20
#   2) Fit y = A * r^{-s}
freq = np.sort(hist)[::-1]
ranks = np.arange(1, len(freq)+1, dtype=float)

def power_law_rank(r, A, s):
    return A * np.power(r, -s)

def r2_and_adj(y, yhat, k_params):
    ss_res = np.sum((y - yhat)**2)
    ss_tot = np.sum((y - y.mean())**2)
    r2 = 1 - ss_res/ss_tot if ss_tot > 0 else np.nan
    n = len(y)
    r2_adj = 1 - (1 - r2)*(n - 1)/(n - k_params - 1) if n > k_params + 1 else np.nan
    return r2, r2_adj

# Nonlinear least squares fit
p0 = [freq[0] if len(freq)>0 else 1.0, 1.0]
popt, pcov = curve_fit(power_law_rank, ranks, freq, p0=p0, bounds=(0, np.inf), maxfev=20000)
A_hat, s_hat = popt
yhat = power_law_rank(ranks, *popt)

# 90% confidence intervals for A and s (normal approximation around the estimate)
z = stats.norm.ppf(0.95)  # two-sided 90% CI
perr = np.sqrt(np.diag(pcov))
A_ci = (A_hat - z*perr[0], A_hat + z*perr[0])
s_ci = (s_hat - z*perr[1], s_hat + z*perr[1])

# R² and adjusted R²
r2, r2_adj = r2_and_adj(freq, yhat, k_params=2)

print("Zipf fit on LINKED TOKENS/page (histogram ranks):")
print(f"  A = {A_hat:.6g}    90% CI = [{A_ci[0]:.6g}, {A_ci[1]:.6g}]")
print(f"  s = {s_hat:.6g}    90% CI = [{s_ci[0]:.6g}, {s_ci[1]:.6g}]")
print(f"  R^2 = {r2:.6g}     Adjusted R^2 = {r2_adj:.6g}")

plt.plot(ranks, freq, marker='o', linestyle='none', label='Observed (bin freq)')
plt.plot(ranks, yhat, linestyle='-', label='Zipf fit')
plt.xlabel("Bin rank (1 = highest frequency)")
plt.ylabel("Frequency")
plt.title("Task 5 — Linked tokens per page: histogram rank vs frequency (Zipf fit)")
plt.legend()
plt.show()

# For consistency with Task 4, also fit a simple power law directly to the histogram (counts vs bin midpoints):
mids = 0.5 * (edges[:-1] + edges[1:])

def pl_x(x, a, b):
    # y = a * x^{-b} ; use a small floor on x to avoid zero / negative issues
    return a * np.power(np.maximum(x, 1e-9), -b)

popt2, pcov2 = curve_fit(pl_x, mids, hist, p0=[max(hist) if len(hist)>0 else 1.0, 1.0],
                         bounds=(0, np.inf), maxfev=20000)
yfit2 = pl_x(mids, *popt2)

# R² for the direct histogram fit
ss_res = np.sum((hist - yfit2)**2)
ss_tot = np.sum((hist - hist.mean())**2)
r2_curve = 1 - ss_res/ss_tot if ss_tot > 0 else np.nan
r2_curve_adj = 1 - (1 - r2_curve)*(len(hist) - 1)/(len(hist) - 2 - 1) if len(hist) > 3 else np.nan

print("\nCurve fit on the histogram (same spirit as Task 4):")
print(f"  a, b = {popt2[0]:.6g}, {popt2[1]:.6g}   R^2 = {r2_curve:.6g}   Adj R^2 = {r2_curve_adj:.6g}")

plt.bar(mids, hist, width=(mids[1]-mids[0]) if len(mids)>1 else 1.0, align='center')
plt.plot(mids, yfit2)
plt.xlabel("Linked tokens per page (bin mid)")
plt.ylabel("Count")
plt.title("Task 5 — Histogram + curve fit (linked tokens)")
plt.show()

# %% [markdown]
# Note: the VRT release has no hyperlink anchors. We approximate “linked tokens” with UPOS=PROPN (proper nouns), which typically correspond to named entities that Wikipedia links.

# %%
# Task 6 — Heaps' law: cumulative linked entities C(k) vs total tokens I(k)

# Definition used here:
# - "linked entities" ≈ count of PROPN tokens (same proxy as Task 5).
# - We order pages by doc_id (deterministic choice) and accumulate:
#       I(k) = sum_{i=1..k} tokens_per_doc[i]
#       C(k) = sum_{i=1..k} linked_tokens_per_doc[i]
# Then we fit Heaps' law: C = K * I^beta, and compute R^2, adjusted R^2, and a 90% CI band.

# Reuse per-page table from Task 5; rebuild if needed
if 'task5' not in globals():
    if 'df' not in globals():
        df = pd.read_parquet("merged_corpus.parquet")
    tokens_per_doc = df.groupby('doc_id').size().astype(int)
    linked_tokens_per_doc = (df['upos'].eq('PROPN')).groupby(df['doc_id']).sum().astype(int)
    task5 = (
        pd.DataFrame({
            'tokens_per_doc': tokens_per_doc,
            'linked_tokens_per_doc': linked_tokens_per_doc
        })
        .reset_index()
        .rename(columns={'index': 'doc_id'})
    )

# Order pages (doc_id ascending is a simple, reproducible choice)
t6 = task5.sort_values('doc_id').reset_index(drop=True)

# Cumulative totals
I = t6['tokens_per_doc'].cumsum().to_numpy(dtype=float)   # total tokens up to k
C = t6['linked_tokens_per_doc'].cumsum().to_numpy(dtype=float)  # total "linked entities" up to k

# Heaps' law model
def heaps(x, K, beta):
    return K * np.power(x, beta)

# Only fit on positive I and C
mask = (I > 0) & (C >= 0)
I_fit = I[mask]
C_fit = C[mask]

# Nonlinear least-squares fit with positivity bounds
popt, pcov = curve_fit(heaps, I_fit, C_fit, p0=[1.0, 0.5], bounds=(0, np.inf), maxfev=20000)
K_hat, beta_hat = popt

# Predictions and goodness-of-fit
C_hat = heaps(I_fit, *popt)

ss_res = np.sum((C_fit - C_hat)**2)
ss_tot = np.sum((C_fit - C_fit.mean())**2)
R2 = 1 - ss_res/ss_tot if ss_tot > 0 else np.nan
n = len(C_fit); k_params = 2
R2_adj = 1 - (1 - R2) * (n - 1) / (n - k_params - 1) if n > k_params + 1 else np.nan

# 90% confidence intervals for parameters (normal approximation)
z = stats.norm.ppf(0.95)  # two-sided 90% CI
perr = np.sqrt(np.diag(pcov))
K_ci = (K_hat - z*perr[0], K_hat + z*perr[0])
beta_ci = (beta_hat - z*perr[1], beta_hat + z*perr[1])

print("Heaps' law fit (C = K * I^beta):")
print(f"  K = {K_hat:.6g}    90% CI = [{K_ci[0]:.6g}, {K_ci[1]:.6g}]")
print(f"  beta = {beta_hat:.6g}    90% CI = [{beta_ci[0]:.6g}, {beta_ci[1]:.6g}]")
print(f"  R^2 = {R2:.6g}     Adjusted R^2 = {R2_adj:.6g}")

#  90% confidence band for the curve (prediction band via parameter sampling)
# Sample parameters from multivariate normal (center = popt, covariance = pcov).
# This gives an empirical 90% envelope for C(I).
rng = np.random.default_rng(42)
n_draws = 300  # enough for a smooth band without being slow
param_samples = rng.multivariate_normal(mean=popt, cov=pcov, size=n_draws)

# Enforce positivity on sampled parameters
param_samples[:, 0] = np.clip(param_samples[:, 0], 1e-12, np.inf)   # K > 0
param_samples[:, 1] = np.clip(param_samples[:, 1], 1e-12, np.inf)   # beta > 0

I_plot = np.linspace(I_fit.min(), I_fit.max(), 400)
C_draws = np.array([heaps(I_plot, K, b) for K, b in param_samples])
C_lo = np.percentile(C_draws, 5, axis=0)   # 90% band
C_hi = np.percentile(C_draws, 95, axis=0)
C_fit_curve = heaps(I_plot, *popt)

# Plot: C vs I with fitted curve and 90% band
plt.plot(I_fit, C_fit, marker='.', linestyle='none', alpha=0.35, label='Cumulative data')
plt.plot(I_plot, C_fit_curve, linestyle='-', label="Heaps' fit")
plt.fill_between(I_plot, C_lo, C_hi, alpha=0.2, label='90% confidence band')
plt.xlabel("I(k): cumulative tokens")
plt.ylabel("C(k): cumulative linked entities (PROPN)")
plt.title("Task 6 — Heaps' law: C vs I with 90% confidence band")
plt.legend()
plt.show()

# Log–log visualization that can be useful for power-law style relations
plt.plot(np.log10(I_fit), np.log10(C_fit + 1e-12), marker='.', linestyle='none', alpha=0.35)
plt.plot(np.log10(I_plot), np.log10(C_fit_curve + 1e-12), linestyle='-')
plt.xlabel("log10 I(k)")
plt.ylabel("log10 C(k)")
plt.title("Task 6 — C vs I (log–log view)")
plt.show()

# %% [markdown]
# We keep the same proxy as **Task 5** (`PROPN` ≈ linked entities) because the VRT release has no hyperlink markup.
#
# Pages are accumulated in **doc_id** order (any deterministic ordering is acceptable; results are stable at large scale).
#
# We report the fitted parameters **K** and **β**, along with **R²**, **adjusted R²**, and show a **90% confidence band** obtained by sampling parameters from the fitted covariance matrix.

# %%
# TAKE ~~1hour !!!

# Task 7 — Counting Location (L) and Organization (P) Entities per Page

# We approximate “linked entities” by using Named Entity Recognition (NER)
# on the page text to detect entities related to Locations and Organizations.

#  Define where the .VRT files are located (recursively handles nested folders)
ROOT = Path.cwd() / "wikipedia-fi-2017-src"
vrt_files = sorted(ROOT.rglob("*.VRT"))
assert vrt_files, "No VRT files found. Check that wikipedia-fi-2017-src/ exists next to the notebook."

# Robust document iterator for .VRT files
DOC_START_RE = re.compile(r'<doc\b[^>]*id="([^"]+)"', re.I)
TITLE_RE = re.compile(r'<doc\b[^>]*title="([^"]+)"', re.I)
DOC_END_RE = re.compile(r'</doc>', re.I)

def is_token_line(line: str) -> bool:
    return ("\t" in line) and (len(line.split("\t")) >= 2) and (not line.startswith("<"))

def iter_docs_tokens(vrt_paths):
    """Yield (doc_id, title, tokens) tuples from VRT files."""
    cur_id, title, toks = None, None, []
    for path in vrt_paths:
        with open(path, encoding="utf-8", errors="replace") as f:
            for raw in f:
                line = raw.rstrip("\n")
                if not line:
                    continue
                # New document
                if DOC_START_RE.search(line):
                    if cur_id is not None and toks:
                        yield cur_id, title, toks
                    cur_id = DOC_START_RE.search(line).group(1)
                    title_match = TITLE_RE.search(line)
                    title = title_match.group(1) if title_match else None
                    toks = []
                    continue
                # End of document
                if DOC_END_RE.search(line):
                    if cur_id is not None and toks:
                        yield cur_id, title, toks
                    cur_id, title, toks = None, None, []
                    continue
                # Token line
                if is_token_line(line):
                    parts = line.split("\t", 2)
                    toks.append(parts[1])
            # Flush last doc
            if cur_id is not None and toks:
                yield cur_id, title, toks
            cur_id, title, toks = None, None, []

#  Load Finnish spaCy model (install if needed)
os.environ.setdefault("THINC_NO_TORCH", "1")  # Avoid Torch issues on Windows
try:
    nlp = spacy.load("fi_core_news_sm")
except OSError:
    import sys, subprocess
    subprocess.run([sys.executable, "-m", "spacy", "download", "fi_core_news_sm"], check=True)
    nlp = spacy.load("fi_core_news_sm")

# Keep only the NER component for speed
for pipe in list(nlp.pipe_names):
    if pipe != "ner":
        nlp.disable_pipes(pipe)
nlp.max_length = 3_000_000

#  NER pass: count LOC and ORG entities per page
rows = []
for doc_id, title, toks in tqdm(iter_docs_tokens(vrt_files), desc="Processing pages", unit="page"):
    text = " ".join(toks)
    doc = nlp(text)
    loc_count = sum(1 for ent in doc.ents if ent.label_.upper() in {"LOC", "GPE", "PLACE"})
    org_count = sum(1 for ent in doc.ents if ent.label_.upper() in {"ORG", "NORP"})
    rows.append((doc_id, title, loc_count, org_count))

# Build the dataframe
df_loc_org = pd.DataFrame(rows, columns=["doc_id", "title", "loc_count", "org_count"])
df_loc_org["loc_count"] = df_loc_org["loc_count"].astype(int)
df_loc_org["org_count"] = df_loc_org["org_count"].astype(int)

#  Save results for later tasks
df_loc_org.to_parquet("fiwiki_loc_org_per_page.parquet", index=False)

print("✅ Finished processing.")
print(f"Total pages analyzed: {len(df_loc_org)}")
display(df_loc_org.head())
# Out:
# Processing pages: 116page [00:13,  8.75page/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1243834400.py in <cell line: 0>()
#      71 for doc_id, title, toks in tqdm(iter_docs_tokens(vrt_files), desc="Processing pages", unit="page"):
#      72     text = " ".join(toks)
# ---> 73     doc = nlp(text)
#      74     loc_count = sum(1 for ent in doc.ents if ent.label_.upper() in {"LOC", "GPE", "PLACE"})
#      75     org_count = sum(1 for ent in doc.ents if ent.label_.upper() in {"ORG", "NORP"})
#
# /usr/local/lib/python3.12/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1039         DOCS: https://spacy.io/api/language#call
#    1040         """
# -> 1041         doc = self._ensure_doc(text)
#    1042         if component_cfg is None:
#    1043             component_cfg = {}
#
# /usr/local/lib/python3.12/dist-packages/spacy/language.py in _ensure_doc(self, doc_like)
#    1130             return doc_like
#    1131         if isinstance(doc_like, str):
# -> 1132             return self.make_doc(doc_like)
#    1133         if isinstance(doc_like, bytes):
#    1134             return Doc(self.vocab).from_bytes(doc_like)
#
# /usr/local/lib/python3.12/dist-packages/spacy/language.py in make_doc(self, text)
#    1122                 Errors.E088.format(length=len(text), max_length=self.max_length)
#    1123             )
# -> 1124         return self.tokenizer(text)
#    1125
#    1126     def _ensure_doc(self, doc_like: Union[str, Doc, bytes]) -> Doc:
#
# /usr/local/lib/python3.12/dist-packages/spacy/tokenizer.pyx in spacy.tokenizer.Tokenizer.__call__()
#
# /usr/local/lib/python3.12/dist-packages/spacy/tokenizer.pyx in spacy.tokenizer.Tokenizer._tokenize_affixes()
#
# /usr/local/lib/python3.12/dist-packages/spacy/tokenizer.pyx in spacy.tokenizer.Tokenizer._tokenize()
#
# /usr/local/lib/python3.12/dist-packages/spacy/tokenizer.pyx in spacy.tokenizer.Tokenizer._attach_tokens()
#
# /usr/local/lib/python3.12/dist-packages/spacy/vocab.pyx in spacy.vocab.Vocab.get()
#
# /usr/local/lib/python3.12/dist-packages/spacy/vocab.pyx in spacy.vocab.Vocab._new_lexeme()
#
# /usr/local/lib/python3.12/dist-packages/spacy/lang/lex_attrs.py in lower(string)
#     142
#     143
# --> 144 def lower(string: str) -> str:
#     145     return string.lower()
#     146
#
# KeyboardInterrupt:

# %% [markdown]
# ### Validation and analysis of Task 7 results
# This block summarizes and visualizes the number of Location and Organization entities per page.

# %%
# df_loc_org = pd.read_parquet("fiwiki_loc_org_per_page.parquet")

print("Rows:", len(df_loc_org))
print("Null titles:", df_loc_org['title'].isna().sum())
print(df_loc_org[['loc_count','org_count']].describe(percentiles=[0.1,0.5,0.9,0.99]))

# % of pages with at least one L/ORG
pct_loc = (df_loc_org['loc_count']>0).mean()*100
pct_org = (df_loc_org['org_count']>0).mean()*100
print(f"Pages with ≥1 Location: {pct_loc:.1f}%")
print(f"Pages with ≥1 Organization: {pct_org:.1f}%")

# Top pages by counts
print("\nTop 10 by Location:")
display(df_loc_org.sort_values('loc_count', ascending=False).head(10))
print("\nTop 10 by Organization:")
display(df_loc_org.sort_values('org_count', ascending=False).head(10))

# Histograms (log y to see tails)
plt.hist(df_loc_org['loc_count'], bins=50, log=True)
plt.xlabel("Location entities per page"); plt.ylabel("Frequency (log)")
plt.title("Distribution of Location entities/page")
plt.show()

plt.hist(df_loc_org['org_count'], bins=50, log=True)
plt.xlabel("Organization entities per page"); plt.ylabel("Frequency (log)")
plt.title("Distribution of Organization entities/page")
plt.show()

# Merge to see densities and correlations
try:
    task5  # has tokens_per_doc
    merged = df_loc_org.merge(task5[['doc_id','tokens_per_doc']], on='doc_id', how='left')
    merged['loc_per_1k'] = merged['loc_count'] / (merged['tokens_per_doc'].replace(0, np.nan)/1000)
    merged['org_per_1k'] = merged['org_count'] / (merged['tokens_per_doc'].replace(0, np.nan)/1000)
    print("\nDensities (entities per 1k tokens):")
    display(merged[['loc_per_1k','org_per_1k']].describe(percentiles=[0.1,0.5,0.9,0.99]))
except NameError:
    pass

# %% [markdown]
# ### Interpretation of task 7
#
# Named-entity counts for locations and organizations follow a heavy-tailed distribution.
# Most Wikipedia pages mention few entities, while list-type articles dominate the upper tail.
# Roughly **80 %** of pages contain at least one *Location* and **84 %** at least one *Organization*,
# showing that these semantic categories are pervasive throughout Finnish Wikipedia.
#
# This confirms that the Finnish NER model (`fi_core_news_sm`) correctly identifies common entity types,
# even though list-style articles strongly influence the extreme values of the distribution.

# %%
# Task 8 — "Leaps' law" for Locations: cumulative L(k) vs number of pages k

# We use the per-page counts from Task 7 (df_loc_org), where loc_count is the number of
# Location entities on a page. We accumulate pages in doc_id order (deterministic),
# compute L(k) = sum_{i=1..k} loc_count[i], and fit:  L(k) = K * k^β.

# Load Task 7 results if not already present
if 'df_loc_org' not in globals():
    df_loc_org = pd.read_parquet("fiwiki_loc_org_per_page.parquet")

# Deterministic ordering (any fixed order is acceptable at this scale)
t8 = df_loc_org.sort_values('doc_id').reset_index(drop=True)

# k = 1..K (number of pages), L(k) = cumulative location entities
k = np.arange(1, len(t8) + 1, dtype=float)
L = t8['loc_count'].cumsum().to_numpy(dtype=float)

# Power-law model: L = K * k^β
def power_pages(x, K, beta):
    return K * np.power(x, beta)

# Fit on all points (nonlinear least squares, positive params)
popt, pcov = curve_fit(power_pages, k, L, p0=[1.0, 0.8], bounds=(0, np.inf), maxfev=20000)
K_hat, beta_hat = popt

# Predictions and fit quality
L_hat = power_pages(k, *popt)
ss_res = np.sum((L - L_hat)**2)
ss_tot = np.sum((L - L.mean())**2)
R2 = 1 - ss_res/ss_tot if ss_tot > 0 else np.nan
n = len(L); k_params = 2
R2_adj = 1 - (1 - R2) * (n - 1) / (n - k_params - 1) if n > k_params + 1 else np.nan

# 90% confidence intervals for parameters
z = stats.norm.ppf(0.95)  # two-sided 90% CI
perr = np.sqrt(np.diag(pcov))
K_ci = (K_hat - z*perr[0], K_hat + z*perr[0])
beta_ci = (beta_hat - z*perr[1], beta_hat + z*perr[1])

print("Leaps' law fit for LOC (L = K * k^β):")
print(f"  K = {K_hat:.6g}    90% CI = [{K_ci[0]:.6g}, {K_ci[1]:.6g}]")
print(f"  β = {beta_hat:.6g}   90% CI = [{beta_ci[0]:.6g}, {beta_ci[1]:.6g}]")
print(f"  R^2 = {R2:.6g}     Adjusted R^2 = {R2_adj:.6g}")

# --- 90% confidence band for the curve via parameter sampling ---
rng = np.random.default_rng(0)
n_draws = 300
param_samples = rng.multivariate_normal(mean=popt, cov=pcov, size=n_draws)
param_samples[:, 0] = np.clip(param_samples[:, 0], 1e-12, np.inf)  # K>0
param_samples[:, 1] = np.clip(param_samples[:, 1], 1e-12, np.inf)  # β>0

k_plot = np.linspace(k.min(), k.max(), 400)
L_draws = np.array([power_pages(k_plot, K_s, b_s) for K_s, b_s in param_samples])
L_lo = np.percentile(L_draws, 5, axis=0)
L_hi = np.percentile(L_draws, 95, axis=0)
L_fit_curve = power_pages(k_plot, *popt)

# Plot: L vs k with fitted curve and 90% band
plt.plot(k, L, marker='.', linestyle='none', alpha=0.35, label='Cumulative L(k)')
plt.plot(k_plot, L_fit_curve, linestyle='-', label="Leaps' fit (LOC)")
plt.fill_between(k_plot, L_lo, L_hi, alpha=0.2, label='90% confidence band')
plt.xlabel("k: number of pages")
plt.ylabel("L(k): cumulative Location entities")
plt.title("Task 8 — Leaps' law for Locations: L(k) vs pages (with 90% band)")
plt.legend()
plt.show()

# Log–log view (slope ≈ β)
plt.plot(np.log10(k), np.log10(L + 1e-12), marker='.', linestyle='none', alpha=0.35)
plt.plot(np.log10(k_plot), np.log10(L_fit_curve + 1e-12), linestyle='-')
plt.xlabel("log10 k (pages)")
plt.ylabel("log10 L(k)")
plt.title("Task 8 — L(k) vs k (log–log view)")
plt.show()

# %% [markdown]
# ### Interpretation of Task 8
#
# The cumulative number of Location entities grows nearly linearly with the number of pages,
# following a power-law relation \(L = K\,k^{\beta}\) with \(K \approx 1.71\) and \(\beta \approx 1.09\).
# The fit exhibits an excellent determination coefficient (\(R^2 \approx 0.999\)), confirming the stability
# of Leaps’ law on this dataset. The log–log view is almost a straight line,
# indicating that cumulative Location mentions scale consistently across Wikipedia pages.
# Deviations at very low \(k\) reflect the variability in early pages with fewer linked entities.

# %% [markdown]
# ### Task 9: Methodology
#
# We accumulate pages in **doc_id order** and compute \( P(k) \), the cumulative number of **Organization** entities after \( k \) pages.
# We then fit the **power-law form** \( P = K\,k^{\beta} \) (same procedure as Task 8), and report the fitted parameters **\(K\)** and **\(\beta\)**, along with **\(R^2\)** and **adjusted \(R^2\)**.
# We visualize the fit and add a **90% confidence band** by sampling parameters from the fitted covariance matrix.

# %%
# Task 9 — "Leaps' law" for Organizations: cumulative P(k) vs number of pages k

# Using Task 7 results (df_loc_org), where org_count = number of Organization entities per page.
# We accumulate pages in doc_id order:
#   P(k) = sum_{i=1..k} org_count[i]
# and fit the power-law:  P = K * k^β
# We report K, β, R², adjusted R², and plot a 90% confidence band via parameter sampling.

# Load per-page LOC/ORG counts (from Task 7) if not already in memory
if 'df_loc_org' not in globals():
    df_loc_org = pd.read_parquet("fiwiki_loc_org_per_page.parquet")

# Deterministic ordering
t9 = df_loc_org.sort_values('doc_id').reset_index(drop=True)

# k = 1..K (pages), P(k) = cumulative Organization entities
k = np.arange(1, len(t9) + 1, dtype=float)
P = t9['org_count'].cumsum().to_numpy(dtype=float)

# Power-law model: P = K * k^β
def power_pages(x, K, beta):
    return K * np.power(x, beta)

# Nonlinear least squares fit with positive parameters
popt, pcov = curve_fit(power_pages, k, P, p0=[1.0, 0.8], bounds=(0, np.inf), maxfev=20000)
K_hat, beta_hat = popt

# Predictions and goodness-of-fit
P_hat = power_pages(k, *popt)
ss_res = np.sum((P - P_hat)**2)
ss_tot = np.sum((P - P.mean())**2)
R2 = 1 - ss_res/ss_tot if ss_tot > 0 else np.nan
n = len(P); k_params = 2
R2_adj = 1 - (1 - R2) * (n - 1) / (n - k_params - 1) if n > k_params + 1 else np.nan

# 90% confidence intervals for parameters (normal approx.)
z = stats.norm.ppf(0.95)  # two-sided 90% CI
perr = np.sqrt(np.diag(pcov))
K_ci = (K_hat - z*perr[0], K_hat + z*perr[0])
beta_ci = (beta_hat - z*perr[1], beta_hat + z*perr[1])

print("Leaps' law fit for ORG (P = K * k^β):")
print(f"  K = {K_hat:.6g}    90% CI = [{K_ci[0]:.6g}, {K_ci[1]:.6g}]")
print(f"  β = {beta_hat:.6g}   90% CI = [{beta_ci[0]:.6g}, {beta_ci[1]:.6g}]")
print(f"  R^2 = {R2:.6g}     Adjusted R^2 = {R2_adj:.6g}")

# --- 90% confidence band via parameter sampling ---
rng = np.random.default_rng(0)
n_draws = 300
param_samples = rng.multivariate_normal(mean=popt, cov=pcov, size=n_draws)
param_samples[:, 0] = np.clip(param_samples[:, 0], 1e-12, np.inf)  # K>0
param_samples[:, 1] = np.clip(param_samples[:, 1], 1e-12, np.inf)  # β>0

k_plot = np.linspace(k.min(), k.max(), 400)
P_draws = np.array([power_pages(k_plot, Ks, bs) for Ks, bs in param_samples])
P_lo = np.percentile(P_draws, 5, axis=0)   # 90% band
P_hi = np.percentile(P_draws, 95, axis=0)
P_fit_curve = power_pages(k_plot, *popt)

# Plot: P vs k with fitted curve and 90% band
plt.plot(k, P, marker='.', linestyle='none', alpha=0.35, label='Cumulative P(k)')
plt.plot(k_plot, P_fit_curve, linestyle='-', label="Leaps' fit (ORG)")
plt.fill_between(k_plot, P_lo, P_hi, alpha=0.2, label='90% confidence band')
plt.xlabel("k: number of pages")
plt.ylabel("P(k): cumulative Organization entities")
plt.title("Task 9 — Leaps' law for Organizations: P(k) vs pages (with 90% band)")
plt.legend()
plt.show()

# Log–log view (slope ≈ β)
plt.plot(np.log10(k), np.log10(P + 1e-12), marker='.', linestyle='none', alpha=0.35)
plt.plot(np.log10(k_plot), np.log10(P_fit_curve + 1e-12), linestyle='-')
plt.xlabel("log10 k (pages)")
plt.ylabel("log10 P(k)")
plt.title("Task 9 — P(k) vs k (log–log view)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-273383068.py in <cell line: 0>()
#       9 # Load per-page LOC/ORG counts (from Task 7) if not already in memory
#      10 if 'df_loc_org' not in globals():
# ---> 11     df_loc_org = pd.read_parquet("fiwiki_loc_org_per_page.parquet")
#      12
#      13 # Deterministic ordering
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     665     check_dtype_backend(dtype_backend)
#     666
# --> 667     return impl.read(
#     668         path,
#     669         columns=columns,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parquet.py in read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     265             to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
#     266
# --> 267         path_or_handle, handles, filesystem = _get_path_or_handle(
#     268             path,
#     269             filesystem,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parquet.py in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     138         # fsspec resources can also point to directories
#     139         # this branch is used for example when reading from non-fsspec URLs
# --> 140         handles = get_handle(
#     141             path_or_handle, mode, is_text=False, storage_options=storage_options
#     142         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fiwiki_loc_org_per_page.parquet'

# %% [markdown]
# # Task 10

# %%
# Task  10 — Entity Length Distributions (Locations L and Organizations P)

#  Define where the .VRT files are located (recursively handles nested folders)
ROOT = Path.cwd() / "wikipedia-fi-2017-src"
vrt_files = sorted(ROOT.rglob("*.VRT"))
assert vrt_files, "No VRT files found. Check that wikipedia-fi-2017-src/ exists next to the notebook."

# Robust document iterator for .VRT files
DOC_START_RE = re.compile(r'<doc\b[^>]*id="([^"]+)"', re.I)
TITLE_RE = re.compile(r'<doc\b[^>]*title="([^"]+)"', re.I)
DOC_END_RE = re.compile(r'</doc>', re.I)

def is_token_line(line: str) -> bool:
    return ("\t" in line) and (len(line.split("\t")) >= 2) and (not line.startswith("<"))

def iter_docs_tokens(vrt_paths):
    """Yield (doc_id, title, tokens) tuples from VRT files."""
    cur_id, title, toks = None, None, []
    for path in vrt_paths:
        with open(path, encoding="utf-8", errors="replace") as f:
            for raw in f:
                line = raw.rstrip("\n")
                if not line:
                    continue
                # New document
                if DOC_START_RE.search(line):
                    if cur_id is not None and toks:
                        yield cur_id, title, toks
                    cur_id = DOC_START_RE.search(line).group(1)
                    title_match = TITLE_RE.search(line)
                    title = title_match.group(1) if title_match else None
                    toks = []
                    continue
                # End of document
                if DOC_END_RE.search(line):
                    if cur_id is not None and toks:
                        yield cur_id, title, toks
                    cur_id, title, toks = None, None, []
                    continue
                # Token line
                if is_token_line(line):
                    parts = line.split("\t", 2)
                    toks.append(parts[1])
            # Flush last doc
            if cur_id is not None and toks:
                yield cur_id, title, toks
            cur_id, title, toks = None, None, []


loc_lengths = []
org_lengths = []

print("Extracting entity lengths (this may take ~1 h)...")
for doc_id, title, toks in tqdm(iter_docs_tokens(vrt_files), desc="Processing pages", unit="page"):
    text = " ".join(toks)
    doc = nlp(text)
    for ent in doc.ents:
        ent_len = len(ent.text)
        label = ent.label_.upper()
        if label in {"LOC", "GPE", "PLACE"}:
            loc_lengths.append(ent_len)
        elif label in {"ORG", "NORP"}:
            org_lengths.append(ent_len)

print(f"✅ Finished.  {len(loc_lengths)} location entities, {len(org_lengths)} organization entities found.")

# Convert to numpy arrays
import numpy as np
loc_lengths = np.array(loc_lengths)
org_lengths = np.array(org_lengths)

# Build 10 bins between the smallest and largest lengths observed
if len(loc_lengths) == 0 or len(org_lengths) == 0:
    print("⚠️ No entities detected; cannot plot histogram.")
else:
    min_len = min(loc_lengths.min(), org_lengths.min())
    max_len = max(loc_lengths.max(), org_lengths.max())
    bins = np.linspace(min_len, max_len, 11)  # 10 bins → 11 edges

    import matplotlib.pyplot as plt

    plt.figure(figsize=(10,6))
    plt.hist(loc_lengths, bins=bins, alpha=0.6, label="Location entities (L)")
    plt.hist(org_lengths, bins=bins, alpha=0.6, label="Organization entities (P)")
    plt.xlabel("Entity length (characters)")
    plt.ylabel("Frequency")
    plt.title("Distribution of Entity Lengths: Locations (L) vs Organizations (P)")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()

    # Optional: summary statistics
    import pandas as pd
    print("Location entity lengths summary:")
    display(pd.Series(loc_lengths).describe())
    print("Organization entity lengths summary:")
    display(pd.Series(org_lengths).describe())
# Out:
# Extracting entity lengths (this may take ~1 h)...
# Processing pages: 425506page [2:22:45, 49.68page/s]
# ✅ Finished.  2300858 location entities, 2186322 organization entities found.
# Location entity lengths summary:
# count    2.300858e+06
# mean     9.233953e+00
# std      3.549778e+00
# min      1.000000e+00
# 25%      7.000000e+00
# 50%      9.000000e+00
# 75%      1.100000e+01
# max      9.300000e+01
# dtype: float64
# Organization entity lengths summary:
# count    2.186322e+06
# mean     1.299318e+01
# std      7.297075e+00
# min      1.000000e+00
# 25%      8.000000e+00
# 50%      1.100000e+01
# 75%      1.600000e+01
# max      1.970000e+02
# dtype: float64
